# %% [markdown]
# # Programming Exercise 4: Neural Networks Learning
#
# ## Introduction
#
# In this exercise, you will implement the backpropagation algorithm for neural networks and apply it to the task of hand-written digit recognition. Before starting on the programming exercise, we strongly recommend watching the video lectures and completing the review questions for the associated topics.
#
# All the information you need for solving this assignment is in this notebook, and all the code you will be implementing will take place within this notebook. The assignment can be promptly submitted to the coursera grader directly from this notebook (code and instructions are included below).
#
# Before we begin with the exercises, we need to import all libraries required for this programming exercise. Throughout the course, we will be using [`numpy`](http://www.numpy.org/) for all arrays and matrix operations, [`matplotlib`](https://matplotlib.org/) for plotting, and [`scipy`](https://docs.scipy.org/doc/scipy/reference/) for scientific and numerical computation functions and tools. You can find instructions on how to install required libraries in the README file in the [github repository](https://github.com/dibgerge/ml-coursera-python-assignments).

# %%
# used for manipulating directory paths
import os

# Scientific and vector computation for python
import numpy as np

# Plotting library
from matplotlib import pyplot

# Optimization module in scipy
from scipy import optimize

# will be used to load MATLAB mat datafile format
from scipy.io import loadmat

from sklearn import metrics

import time 
# random number generator
import random 

import pandas as pd
# library written for this exercise providing additional functions for assignment submission, and others
#import utils

# define the submission/grader object for this exercise
#grader = utils.Grader()

import warnings
warnings.filterwarnings('ignore')


# tells matplotlib to embed plots within the notebook
# %matplotlib inline

# %%
def displayData(X, example_width=None, figsize=(10, 10)):
    """
    Displays 2D data stored in X in a nice grid.
    """
    # Compute rows, cols
    if X.ndim == 2:
        m, n = X.shape
    elif X.ndim == 1:
        n = X.size
        m = 1
        X = X[None]  # Promote to a 2 dimensional array
    else:
        raise IndexError('Input X should be 1 or 2 dimensional.')

    example_width = example_width or int(np.round(np.sqrt(n)))
    example_height = n / example_width

    # Compute number of items to display
    display_rows = int(np.floor(np.sqrt(m)))
    display_cols = int(np.ceil(m / display_rows))

    fig, ax_array = pyplot.subplots(display_rows, display_cols, figsize=figsize)
    fig.subplots_adjust(wspace=0.025, hspace=0.025)

    ax_array = [ax_array] if m == 1 else ax_array.ravel()

    for i, ax in enumerate(ax_array):
        # Display Image
        h = ax.imshow(X[i].reshape(example_width, example_width, order='F'),
                      cmap='Greys', extent=[0, 1, 0, 1])
        ax.axis('off')


def predict(Theta1, Theta2, X):
    """
    Predict the label of an input given a trained neural network
    Outputs the predicted label of X given the trained weights of a neural
    network(Theta1, Theta2)
    """
    # Useful values
    m = X.shape[0]
    num_labels = Theta2.shape[0]

    # You need to return the following variables correctly
    p = np.zeros(m)
    h1 = sigmoid(np.dot(np.concatenate([np.ones((m, 1)), X], axis=1), Theta1.T))
    h2 = sigmoid(np.dot(np.concatenate([np.ones((m, 1)), h1], axis=1), Theta2.T))
    p = np.argmax(h2, axis=1)
    return p


def debugInitializeWeights(fan_out, fan_in):
    """
    Initialize the weights of a layer with fan_in incoming connections and fan_out outgoings
    connections using a fixed strategy. This will help you later in debugging.

    Note that W should be set a matrix of size (1+fan_in, fan_out) as the first row of W handles
    the "bias" terms.

    Parameters
    ----------
    fan_out : int
        The number of outgoing connections.

    fan_in : int
        The number of incoming connections.

    Returns
    -------
    W : array_like (1+fan_in, fan_out)
        The initialized weights array given the dimensions.
    """
    # Initialize W using "sin". This ensures that W is always of the same values and will be
    # useful for debugging
    W = np.sin(np.arange(1, 1 + (1+fan_in)*fan_out))/10.0
    W = W.reshape(fan_out, 1+fan_in, order='F')
    return W


def computeNumericalGradient(J, theta, e=1e-4):
    """
    Computes the gradient using "finite differences" and gives us a numerical estimate of the
    gradient.

    Parameters
    ----------
    J : func
        The cost function which will be used to estimate its numerical gradient.

    theta : array_like
        The one dimensional unrolled network parameters. The numerical gradient is computed at
         those given parameters.

    e : float (optional)
        The value to use for epsilon for computing the finite difference.

    Notes
    -----
    The following code implements numerical gradient checking, and
    returns the numerical gradient. It sets `numgrad[i]` to (a numerical
    approximation of) the partial derivative of J with respect to the
    i-th input argument, evaluated at theta. (i.e., `numgrad[i]` should
    be the (approximately) the partial derivative of J with respect
    to theta[i].)
    """
    numgrad = np.zeros(theta.shape)
    perturb = np.diag(e * np.ones(theta.shape))
    for i in range(theta.size):
        loss1, _ = J(theta - perturb[:, i])
        loss2, _ = J(theta + perturb[:, i])
        numgrad[i] = (loss2 - loss1)/(2*e)
    return numgrad


def checkNNGradients(nnCostFunction, lambda_=0):
    """
    Creates a small neural network to check the backpropagation gradients. It will output the
    analytical gradients produced by your backprop code and the numerical gradients
    (computed using computeNumericalGradient). These two gradient computations should result in
    very similar values.

    Parameters
    ----------
    nnCostFunction : func
        A reference to the cost function implemented by the student.

    lambda_ : float (optional)
        The regularization parameter value.
    """
    input_layer_size = 3
    hidden_layer_size = 5
    num_labels = 3
    m = 5

    # We generate some 'random' test data
    Theta1 = debugInitializeWeights(hidden_layer_size, input_layer_size)
    Theta2 = debugInitializeWeights(num_labels, hidden_layer_size)

    # Reusing debugInitializeWeights to generate X
    X = debugInitializeWeights(m, input_layer_size - 1)
    y = np.arange(1, 1+m) % num_labels
    # print(y)
    # Unroll parameters
    nn_params = np.concatenate([Theta1.ravel(), Theta2.ravel()])

    # short hand for cost function
    costFunc = lambda p: nnCostFunction(p, input_layer_size, hidden_layer_size,
                                        num_labels, X, y, lambda_)
    cost, grad = costFunc(nn_params)
    numgrad = computeNumericalGradient(costFunc, nn_params)

    # Visually examine the two gradient computations.The two columns you get should be very similar.
    print(np.stack([numgrad, grad], axis=1))
    print('The above two columns you get should be very similar.')
    print('(Left-Your Numerical Gradient, Right-Analytical Gradient)\n')

    # Evaluate the norm of the difference between two the solutions. If you have a correct
    # implementation, and assuming you used e = 0.0001 in computeNumericalGradient, then diff
    # should be less than 1e-9.
    diff = np.linalg.norm(numgrad - grad)/np.linalg.norm(numgrad + grad)

    print('If your backpropagation implementation is correct, then \n'
          'the relative difference will be small (less than 1e-9). \n'
          'Relative Difference: %g' % diff)


def sigmoid(z):
    """
    Computes the sigmoid of z.
    """
    return 1.0 / (1.0 + np.exp(-z))

def sigmoidGradient(z):
    """
    Computes the gradient of the sigmoid function evaluated at z. 
    This should work regardless if z is a matrix or a vector. 
    In particular, if z is a vector or matrix, you should return
    the gradient for each element.
    
    Parameters
    ----------
    z : array_like
        A vector or matrix as input to the sigmoid function. 
    
    Returns
    --------
    g : array_like
        Gradient of the sigmoid function. Has the same shape as z. 
    
    Instructions
    ------------
    Compute the gradient of the sigmoid function evaluated at
    each value of z (z can be a matrix, vector or scalar).
    
    Note
    ----
    We have provided an implementation of the sigmoid function 
    in `utils.py` file accompanying this assignment.
    """

    g = np.zeros(z.shape)

    # ====================== YOUR CODE HERE ======================
    
    g = np.multiply(sigmoid(z), 1-sigmoid(z))

    # =============================================================
    return g

# %% [markdown]
# ## Neural Networks
#
# In the previous exercise, you implemented feedforward propagation for neural networks and used it to predict handwritten digits with the weights we provided. In this exercise, you will implement the backpropagation algorithm to learn the parameters for the neural network.
#
# We start the exercise by first loading the dataset.

# %%
#  training data stored in arrays X, y
data = loadmat("Data/ex4data1.mat")
#data = loadmat('/MyDrive/os.path.join('Data', 'ex4data1.mat'))
X, y = data['X'], data['y'].ravel()

# set the zero digit to 0, rather than its mapped 10 in this dataset
# This is an artifact due to the fact that this dataset was used in 
# MATLAB where there is no index 0
y[y == 10] = 0

# Number of training examples
m = y.size

# %% [markdown]
# ### 1.1 Visualizing the data
#
# You will begin by visualizing a subset of the training set, using the function `displayData`, which is the same function we used in Exercise 3. It is provided in the `utils.py` file for this assignment as well. The dataset is also the same one you used in the previous exercise.
#
# There are 5000 training examples in `ex4data1.mat`, where each training example is a 20 pixel by 20 pixel grayscale image of the digit. Each pixel is represented by a floating point number indicating the grayscale intensity at that location. The 20 by 20 grid of pixels is “unrolled” into a 400-dimensional vector. Each
# of these training examples becomes a single row in our data matrix $X$. This gives us a 5000 by 400 matrix $X$ where every row is a training example for a handwritten digit image.
#
# $$
# X = \begin{bmatrix} - \left(x^{(1)} \right)^T - \\
# - \left(x^{(2)} \right)^T - \\
# \vdots \\
# - \left(x^{(m)} \right)^T - \\
# \end{bmatrix}
# $$
#
# The second part of the training set is a 5000-dimensional vector `y` that contains labels for the training set.
# The following cell randomly selects 100 images from the dataset and plots them.

# %%
# Randomly select 100 data points to display
rand_indices = np.random.choice(m, 100, replace=False)
sel = X[rand_indices, :]

displayData(sel)

# %% [markdown]
# ### 1.2 Model representation
#
# Our neural network is shown in the following figure.
#
# ![](Figures/neural_network.png)
#
# It has 3 layers - an input layer, a hidden layer and an output layer. Recall that our inputs are pixel values
# of digit images. Since the images are of size $20 \times 20$, this gives us 400 input layer units (not counting the extra bias unit which always outputs +1). The training data was loaded into the variables `X` and `y` above.
#
# You have been provided with a set of network parameters ($\Theta^{(1)}, \Theta^{(2)}$) already trained by us. These are stored in `ex4weights.mat` and will be loaded in the next cell of this notebook into `Theta1` and `Theta2`. The parameters have dimensions that are sized for a neural network with 25 units in the second layer and 10 output units (corresponding to the 10 digit classes).

# %%
# Setup the parameters you will use for this exercise
input_layer_size  = 400  # 20x20 Input Images of Digits
hidden_layer_size = 25   # 25 hidden units
num_labels = 10          # 10 labels, from 0 to 9

# Load the weights into variables Theta1 and Theta2
weights = loadmat(os.path.join('Data', 'ex4weights.mat'))

# Theta1 has size 25 x 401
# Theta2 has size 10 x 26
Theta1, Theta2 = weights['Theta1'], weights['Theta2']

# swap first and last columns of Theta2, due to legacy from MATLAB indexing, 
# since the weight file ex3weights.mat was saved based on MATLAB indexing
Theta2 = np.roll(Theta2, 1, axis=0)

# Unroll parameters 
nn_params = np.concatenate([Theta1.ravel(), Theta2.ravel()])

# %% [markdown]
# <a id="section1"></a>
#
# ### 1.3 Feedforward and cost function
#
# Now you will implement the cost function and gradient for the neural network. First, complete the code for the function `nnCostFunction` in the next cell to return the cost.
#
# Recall that the cost function for the neural network (without regularization) is:
#
# $$ J(\theta) = \frac{1}{m} \sum*{i=1}^{m}\sum*{k=1}^{K} \left[ - y_k^{(i)} \log \left( \left( h_\theta \left( x^{(i)} \right) \right)_k \right) - \left( 1 - y_k^{(i)} \right) \log \left( 1 - \left( h_\theta \left( x^{(i)} \right) \right)_k \right) \right]$$
#
# where $h_\theta \left( x^{(i)} \right)$ is computed as shown in the neural network figure above, and K = 10 is the total number of possible labels. Note that $h_\theta(x^{(i)})_k = a_k^{(3)}$ is the activation (output
# value) of the $k^{th}$ output unit. Also, recall that whereas the original labels (in the variable y) were 0, 1, ..., 9, for the purpose of training a neural network, we need to encode the labels as vectors containing only values 0 or 1, so that
#
# $$
# y =
# \begin{bmatrix} 1 \\ 0 \\ 0 \\\vdots \\ 0 \end{bmatrix}, \quad
# \begin{bmatrix} 0 \\ 1 \\ 0 \\ \vdots \\ 0 \end{bmatrix}, \quad \cdots  \quad \text{or} \qquad
# \begin{bmatrix} 0 \\ 0 \\ 0 \\ \vdots \\ 1 \end{bmatrix}.
# $$
#
# For example, if $x^{(i)}$ is an image of the digit 5, then the corresponding $y^{(i)}$ (that you should use with the cost function) should be a 10-dimensional vector with $y_5 = 1$, and the other elements equal to 0.
#
# You should implement the feedforward computation that computes $h_\theta(x^{(i)})$ for every example $i$ and sum the cost over all examples. **Your code should also work for a dataset of any size, with any number of labels** (you can assume that there are always at least $K \ge 3$ labels).
#
# <div class="alert alert-box alert-warning">
# **Implementation Note:** The matrix $X$ contains the examples in rows (i.e., X[i,:] is the i-th training example $x^{(i)}$, expressed as a $n \times 1$ vector.) When you complete the code in `nnCostFunction`, you will need to add the column of 1’s to the X matrix. The parameters for each unit in the neural network is represented in Theta1 and Theta2 as one row. Specifically, the first row of Theta1 corresponds to the first hidden unit in the second layer. You can use a for-loop over the examples to compute the cost.
# </div>
# <a id="nnCostFunction"></a>

# %%
from sklearn.preprocessing import OneHotEncoder

def nnCostFunction(nn_params,
                   input_layer_size,
                   hidden_layer_size,
                   num_labels,
                   X, y, lambda_=0.0):
    """
    Implements the neural network cost function and gradient for a two layer neural 
    network which performs classification. 
    
    Parameters
    ----------
    nn_params : array_like
        The parameters for the neural network which are "unrolled" into 
        a vector. This needs to be converted back into the weight matrices Theta1
        and Theta2.
    
    input_layer_size : int
        Number of features for the input layer. 
    
    hidden_layer_size : int
        Number of hidden units in the second layer.
    
    num_labels : int
        Total number of labels, or equivalently number of units in output layer. 
    
    X : array_like
        Input dataset. A matrix of shape (m x input_layer_size).
    
    y : array_like
        Dataset labels. A vector of shape (m,).
    
    lambda_ : float, optional
        Regularization parameter.
 
    Returns
    -------
    J : float
        The computed value for the cost function at the current weight values.
    
    grad : array_like
        An "unrolled" vector of the partial derivatives of the concatenatation of
        neural network weights Theta1 and Theta2.
    
    Instructions
    ------------
    You should complete the code by working through the following parts.
    
    - Part 1: Feedforward the neural network and return the cost in the 
              variable J. After implementing Part 1, you can verify that your
              cost function computation is correct by verifying the cost
              computed in the following cell.
    
    - Part 2: Implement the backpropagation algorithm to compute the gradients
              Theta1_grad and Theta2_grad. You should return the partial derivatives of
              the cost function with respect to Theta1 and Theta2 in Theta1_grad and
              Theta2_grad, respectively. After implementing Part 2, you can check
              that your implementation is correct by running checkNNGradients provided
              in the utils.py module.
    
              Note: The vector y passed into the function is a vector of labels
                    containing values from 0..K-1. You need to map this vector into a 
                    binary vector of 1's and 0's to be used with the neural network
                    cost function.
     
              Hint: We recommend implementing backpropagation using a for-loop
                    over the training examples if you are implementing it for the 
                    first time.
    
    - Part 3: Implement regularization with the cost function and gradients.
    
              Hint: You can implement this around the code for
                    backpropagation. That is, you can compute the gradients for
                    the regularization separately and then add them to Theta1_grad
                    and Theta2_grad from Part 2.
    
    Note 
    ----
    We have provided an implementation for the sigmoid function in the file 
    `utils.py` accompanying this assignment.
    """
    # Reshape nn_params back into the parameters Theta1 and Theta2, the weight matrices
    # for our 2 layer neural network
    Theta1 = np.reshape(nn_params[:hidden_layer_size * (input_layer_size + 1)],
                        (hidden_layer_size, (input_layer_size + 1)))

    Theta2 = np.reshape(nn_params[(hidden_layer_size * (input_layer_size + 1)):],
                        (num_labels, (hidden_layer_size + 1)))

    # Setup some useful variables
    m = y.size

    y = y.reshape(-1, 1)
    y_oh = OneHotEncoder(sparse=False).fit_transform(y)
         
    # You need to return the following variables correctly 
    J = 0
    Theta1_grad = np.zeros(Theta1.shape)
    Theta2_grad = np.zeros(Theta2.shape)

    # ====================== YOUR CODE HERE ======================
    # Useful values
    m = X.shape[0]
    num_labels = Theta2.shape[0]

    #
    # Calculating Cost
    #
    hx = np.zeros(m)
    h1 = sigmoid(np.dot(np.concatenate([np.ones((m, 1)), X], axis=1), Theta1.T))
    hx = sigmoid(np.dot(np.concatenate([np.ones((m, 1)), h1], axis=1), Theta2.T))

    res = -y_oh * np.log(hx) - (1-y_oh) * np.log(1-hx)

    sum_k = np.sum(res, axis=1)
    sum_m = np.sum(sum_k)
    J = sum_m/m

    #
    # Calculating Gradients
    #

    # Add intercept term to X
    X = np.concatenate([np.ones((m, 1)), X], axis=1)

    # Calculate NET z2
    z2 = Theta1 @ X.T
    
    # Calculate activation using sigmoid
    a2 = sigmoid(z2)
    
    # Add bias term to a2
    a2 = np.concatenate([np.ones((1, m)), a2], axis=0)
        
    # Calculate NET z3
    z3 = Theta2 @ a2
    
    # Calculate activation using sigmoid
    a3 = sigmoid(z3)

    p = np.argmax(a3, axis=0)

    # Delta for Theta2        
    

    delta_3 = a3 - y_oh.T

    # Calculate first term of delta_2
    t2_d3 = (Theta2.T @ delta_3)

    # Adding bias term and calculate gradient for sigmoid function
    sigmoid_grad_bias =  np.concatenate([np.ones((1, m)), sigmoidGradient(z2)], axis=0)

    # Calculate Delta 2
    delta_2 = np.multiply(t2_d3, sigmoid_grad_bias)

    # Calculate gradient for second to third layer
    Theta2_grad = (1/m) * delta_3 @ a2.T

    # Remove bias 
    delta_2 = delta_2[1:, :]

    # Calculate gradient for first to second layer
    Theta1_grad =  (1/m) * delta_2 @ X

    # Adding part 3

    # Calculate  Regularized Cost function
    reg_value = (lambda_ / (2*m)) *(np.sum(np.square(Theta1[:, 1:])) + np.sum(np.square(Theta2[:, 1:])))
    J += reg_value

    # Calculate Regularized gradients

    Theta1_grad[:, 1:] =  Theta1_grad[:, 1:] + (lambda_/m)*Theta1[:,1:]
    Theta2_grad[:, 1:] =  Theta2_grad[:, 1:] + (lambda_/m)*Theta2[:,1:]
    # ================================================================
    # Unroll gradients
    # grad = np.concatenate([Theta1_grad.ravel(order=order), Theta2_grad.ravel(order=order)])


    grad = np.concatenate([Theta1_grad.ravel(), Theta2_grad.ravel()])

    return J, grad

# %% [markdown]
# <div class="alert alert-box alert-warning">
# Use the following links to go back to the different parts of this exercise that require to modify the function `nnCostFunction`.<br>
#
# Back to:
#
# - [Feedforward and cost function](#section1)
# - [Regularized cost](#section2)
# - [Neural Network Gradient (Backpropagation)](#section4)
# - [Regularized Gradient](#section5)
# </div>

# %% [markdown]
# Once you are done, call your `nnCostFunction` using the loaded set of parameters for `Theta1` and `Theta2`. You should see that the cost is about 0.287629.

# %%
lambda_ = 0
J, _ = nnCostFunction(nn_params, input_layer_size, hidden_layer_size,
                   num_labels, X, y, lambda_)
print('Cost at parameters (loaded from ex4weights): %.6f ' % J)
print('The cost should be about                   : 0.287629.')
# Out:
# Cost at parameters (loaded from ex4weights): 0.287629
# The cost should be about                   : 0.287629.

# %% [markdown]
# <a id="section2"></a>
#
# ### 1.4 Regularized cost function
#
# The cost function for neural networks with regularization is given by:
#
# $$ J(\theta) = \frac{1}{m} \sum*{i=1}^{m}\sum*{k=1}^{K} \left[ - y_k^{(i)} \log \left( \left( h_\theta \left( x^{(i)} \right) \right)_k \right) - \left( 1 - y_k^{(i)} \right) \log \left( 1 - \left( h_\theta \left( x^{(i)} \right) \right)_k \right) \right] + \frac{\lambda}{2 m} \left[ \sum_{j=1}^{25} \sum_{k=1}^{400} \left( \Theta_{j,k}^{(1)} \right)^2 + \sum_{j=1}^{10} \sum_{k=1}^{25} \left( \Theta_{j,k}^{(2)} \right)^2 \right] $$
#
# You can assume that the neural network will only have 3 layers - an input layer, a hidden layer and an output layer. However, your code should work for any number of input units, hidden units and outputs units. While we
# have explicitly listed the indices above for $\Theta^{(1)}$ and $\Theta^{(2)}$ for clarity, do note that your code should in general work with $\Theta^{(1)}$ and $\Theta^{(2)}$ of any size. Note that you should not be regularizing the terms that correspond to the bias. For the matrices `Theta1` and `Theta2`, this corresponds to the first column of each matrix. You should now add regularization to your cost function. Notice that you can first compute the unregularized cost function $J$ using your existing `nnCostFunction` and then later add the cost for the regularization terms.
#
# [Click here to go back to `nnCostFunction` for editing.](#nnCostFunction)

# %% [markdown]
# Once you are done, the next cell will call your `nnCostFunction` using the loaded set of parameters for `Theta1` and `Theta2`, and $\lambda = 1$. You should see that the cost is about 0.383770.

# %%
# Weight regularization parameter (we set this to 1 here).
lambda_ = 1
J, _ = nnCostFunction(nn_params, input_layer_size, hidden_layer_size,
                      num_labels, X, y, lambda_)

print('Cost at parameters (loaded from ex4weights): %.6f' % J)
print('This value should be about                 : 0.383770.')
# Out:
# Cost at parameters (loaded from ex4weights): 0.383770
# This value should be about                 : 0.383770.

# %% [markdown]
# ## 2 Backpropagation
#
# In this part of the exercise, you will implement the backpropagation algorithm to compute the gradient for the neural network cost function. You will need to update the function `nnCostFunction` so that it returns an appropriate value for `grad`. Once you have computed the gradient, you will be able to train the neural network by minimizing the cost function $J(\theta)$ using an advanced optimizer such as `scipy`'s `optimize.minimize`.
# You will first implement the backpropagation algorithm to compute the gradients for the parameters for the (unregularized) neural network. After you have verified that your gradient computation for the unregularized case is correct, you will implement the gradient for the regularized neural network.

# %% [markdown]
# <a id="section3"></a>
#
# ### 2.1 Sigmoid Gradient
#
# To help you get started with this part of the exercise, you will first implement
# the sigmoid gradient function. The gradient for the sigmoid function can be
# computed as
#
# $$ g'(z) = \frac{d}{dz} g(z) = g(z)\left(1-g(z)\right) $$
#
# where
#
# $$ \text{sigmoid}(z) = g(z) = \frac{1}{1 + e^{-z}} $$
#
# Now complete the implementation of `sigmoidGradient` in the next cell.
# <a id="sigmoidGradient"></a>

# %%
def sigmoidGradient(z):
    """
    Computes the gradient of the sigmoid function evaluated at z. 
    This should work regardless if z is a matrix or a vector. 
    In particular, if z is a vector or matrix, you should return
    the gradient for each element.
    
    Parameters
    ----------
    z : array_like
        A vector or matrix as input to the sigmoid function. 
    
    Returns
    --------
    g : array_like
        Gradient of the sigmoid function. Has the same shape as z. 
    
    Instructions
    ------------
    Compute the gradient of the sigmoid function evaluated at
    each value of z (z can be a matrix, vector or scalar).
    
    Note
    ----
    We have provided an implementation of the sigmoid function 
    in `utils.py` file accompanying this assignment.
    """

    g = np.zeros(z.shape)

    # ====================== YOUR CODE HERE ======================
    
    g = np.multiply(sigmoid(z), 1-sigmoid(z))

    # =============================================================
    return g

# %% [markdown]
# When you are done, the following cell call `sigmoidGradient` on a given vector `z`. Try testing a few values by calling `sigmoidGradient(z)`. For large values (both positive and negative) of z, the gradient should be close to 0. When $z = 0$, the gradient should be exactly 0.25. Your code should also work with vectors and matrices. For a matrix, your function should perform the sigmoid gradient function on every element.

# %%
z = np.array([-1, -0.5, 0, 0.5, 1])
g = sigmoidGradient(z)
print('Sigmoid gradient evaluated at [-1 -0.5 0 0.5 1]:\n  ')
print(g)
# Out:
# Sigmoid gradient evaluated at [-1 -0.5 0 0.5 1]:
#
# [0.19661193 0.23500371 0.25       0.23500371 0.19661193]

# %% [markdown]
# ## 2.2 Random Initialization
#
# When training neural networks, it is important to randomly initialize the parameters for symmetry breaking. One effective strategy for random initialization is to randomly select values for $\Theta^{(l)}$ uniformly in the range $[-\epsilon_{init}, \epsilon_{init}]$. You should use $\epsilon_{init} = 0.12$. This range of values ensures that the parameters are kept small and makes the learning more efficient.
#
# <div class="alert alert-box alert-warning">
# One effective strategy for choosing $\epsilon_{init}$ is to base it on the number of units in the network. A good choice of $\epsilon_{init}$ is $\epsilon_{init} = \frac{\sqrt{6}}{\sqrt{L_{in} + L_{out}}}$ where $L_{in} = s_l$ and $L_{out} = s_{l+1}$ are the number of units in the layers adjacent to $\Theta^{l}$.
# </div>
#
# Your job is to complete the function `randInitializeWeights` to initialize the weights for $\Theta$. Modify the function by filling in the following code:
#
# ```python
# # Randomly initialize the weights to small values
# W = np.random.rand(L_out, 1 + L_in) * 2 * epsilon_init - epsilon_init
# ```
#
# Note that we give the function an argument for $\epsilon$ with default value `epsilon_init = 0.12`.

# %%
def randInitializeWeights(L_in, L_out, epsilon_init=0.12):
    """
    Randomly initialize the weights of a layer in a neural network.
    
    Parameters
    ----------
    L_in : int
        Number of incomming connections.
    
    L_out : int
        Number of outgoing connections. 
    
    epsilon_init : float, optional
        Range of values which the weight can take from a uniform 
        distribution.
    
    Returns
    -------
    W : array_like
        The weight initialiatized to random values.  Note that W should
        be set to a matrix of size(L_out, 1 + L_in) as
        the first column of W handles the "bias" terms.
        
    Instructions
    ------------
    Initialize W randomly so that we break the symmetry while training
    the neural network. Note that the first column of W corresponds 
    to the parameters for the bias unit.
    """

    # You need to return the following variables correctly 
    W = np.zeros((L_out, 1 + L_in))

    # ====================== YOUR CODE HERE ======================
    W = np.random.rand(L_out, 1 + L_in) * 2 * epsilon_init - epsilon_init


    # ============================================================
    return W

# %% [markdown]
# _You do not need to submit any code for this part of the exercise._
#
# Execute the following cell to initialize the weights for the 2 layers in the neural network using the `randInitializeWeights` function.

# %%
def initializeParams():
  
    initial_Theta1 = randInitializeWeights(input_layer_size, hidden_layer_size)
    initial_Theta2 = randInitializeWeights(hidden_layer_size, num_labels)
    
    # Unroll parameters
    _initial_nn_params = np.concatenate([initial_Theta1.ravel(), initial_Theta2.ravel()], axis=0)
    return _initial_nn_params

print('Initializing Neural Network Parameters ...')
initial_nn_params = initializeParams()
# Out:
# Initializing Neural Network Parameters ...

# %% [markdown]
# <a id="section4"></a>
#
# ### 2.4 Backpropagation
#
# ![](Figures/ex4-backpropagation.png)
#
# Now, you will implement the backpropagation algorithm. Recall that the intuition behind the backpropagation algorithm is as follows. Given a training example $(x^{(t)}, y^{(t)})$, we will first run a “forward pass” to compute all the activations throughout the network, including the output value of the hypothesis $h_\theta(x)$. Then, for each node $j$ in layer $l$, we would like to compute an “error term” $\delta_j^{(l)}$ that measures how much that node was “responsible” for any errors in our output.
#
# For an output node, we can directly measure the difference between the network’s activation and the true target value, and use that to define $\delta_j^{(3)}$ (since layer 3 is the output layer). For the hidden units, you will compute $\delta_j^{(l)}$ based on a weighted average of the error terms of the nodes in layer $(l+1)$. In detail, here is the backpropagation algorithm (also depicted in the figure above). You should implement steps 1 to 4 in a loop that processes one example at a time. Concretely, you should implement a for-loop `for t in range(m)` and place steps 1-4 below inside the for-loop, with the $t^{th}$ iteration performing the calculation on the $t^{th}$ training example $(x^{(t)}, y^{(t)})$. Step 5 will divide the accumulated gradients by $m$ to obtain the gradients for the neural network cost function.
#
# 1. Set the input layer’s values $(a^{(1)})$ to the $t^{th }$training example $x^{(t)}$. Perform a feedforward pass, computing the activations $(z^{(2)}, a^{(2)}, z^{(3)}, a^{(3)})$ for layers 2 and 3. Note that you need to add a `+1` term to ensure that the vectors of activations for layers $a^{(1)}$ and $a^{(2)}$ also include the bias unit. In `numpy`, if a 1 is a column matrix, adding one corresponds to `a_1 = np.concatenate([np.ones((m, 1)), a_1], axis=1)`.
#
# 1. For each output unit $k$ in layer 3 (the output layer), set
#    $$\delta_k^{(3)} = \left(a_k^{(3)} - y_k \right)$$
#    where $y_k \in \{0, 1\}$ indicates whether the current training example belongs to class $k$ $(y_k = 1)$, or if it belongs to a different class $(y_k = 0)$. You may find logical arrays helpful for this task (explained in the previous programming exercise).
#
# 1. For the hidden layer $l = 2$, set
#    $$ \delta^{(2)} = \left( \Theta^{(2)} \right)^T \delta^{(3)} \odot g'\left(z^{(2)} \right)$$
#    Note that the symbol $\odot$ performs element wise multiplication in `numpy`.
#
# 1. Accumulate the gradient from this example using the following formula. Note that you should skip or remove $\delta_0^{(2)}$. In `numpy`, removing $\delta_0^{(2)}$ corresponds to `delta_2 = delta_2[1:]`.
#    $$ \Delta^{(l)} = \Delta^{(l)} + \delta^{(l+1)} (a^{(l)})^{(T)} $$
#
# 1. Obtain the (unregularized) gradient for the neural network cost function by dividing the accumulated gradients by $\frac{1}{m}$:
#    $$ \frac{\partial}{\partial \Theta*{ij}^{(l)}} J(\Theta) = D*{ij}^{(l)} = \frac{1}{m} \Delta\_{ij}^{(l)}$$
#
# <div class="alert alert-box alert-warning">
# **Python/Numpy tip**: You should implement the backpropagation algorithm only after you have successfully completed the feedforward and cost functions. While implementing the backpropagation alogrithm, it is often useful to use the `shape` function to print out the shapes of the variables you are working with if you run into dimension mismatch errors.
# </div>
#
# [Click here to go back and update the function `nnCostFunction` with the backpropagation algorithm](#nnCostFunction).
#
# **Note:** If the iterative solution provided above is proving to be difficult to implement, try implementing the vectorized approach which is easier to implement in the opinion of the moderators of this course. You can find the tutorial for the vectorized approach [here](https://www.coursera.org/learn/machine-learning/discussions/all/threads/a8Kce_WxEeS16yIACyoj1Q).

# %% [markdown]
# After you have implemented the backpropagation algorithm, we will proceed to run gradient checking on your implementation. The gradient check will allow you to increase your confidence that your code is
# computing the gradients correctly.
#
# ### 2.4 Gradient checking
#
# In your neural network, you are minimizing the cost function $J(\Theta)$. To perform gradient checking on your parameters, you can imagine “unrolling” the parameters $\Theta^{(1)}$, $\Theta^{(2)}$ into a long vector $\theta$. By doing so, you can think of the cost function being $J(\Theta)$ instead and use the following gradient checking procedure.
#
# Suppose you have a function $f_i(\theta)$ that purportedly computes $\frac{\partial}{\partial \theta_i} J(\theta)$; you’d like to check if $f_i$ is outputting correct derivative values.
#
# $$
# \text{Let } \theta^{(i+)} = \theta + \begin{bmatrix} 0 \\ 0 \\ \vdots \\ \epsilon \\ \vdots \\ 0 \end{bmatrix}
# \quad \text{and} \quad \theta^{(i-)} = \theta - \begin{bmatrix} 0 \\ 0 \\ \vdots \\ \epsilon \\ \vdots \\ 0 \end{bmatrix}
# $$
#
# So, $\theta^{(i+)}$ is the same as $\theta$, except its $i^{th}$ element has been incremented by $\epsilon$. Similarly, $\theta^{(i−)}$ is the corresponding vector with the $i^{th}$ element decreased by $\epsilon$. You can now numerically verify $f_i(\theta)$’s correctness by checking, for each $i$, that:
#
# $$ f_i\left( \theta \right) \approx \frac{J\left( \theta^{(i+)}\right) - J\left( \theta^{(i-)} \right)}{2\epsilon} $$
#
# The degree to which these two values should approximate each other will depend on the details of $J$. But assuming $\epsilon = 10^{-4}$, you’ll usually find that the left- and right-hand sides of the above will agree to at least 4 significant digits (and often many more).
#
# We have implemented the function to compute the numerical gradient for you in `computeNumericalGradient` (within the file `utils.py`). While you are not required to modify the file, we highly encourage you to take a look at the code to understand how it works.
#
# In the next cell we will run the provided function `checkNNGradients` which will create a small neural network and dataset that will be used for checking your gradients. If your backpropagation implementation is correct,
# you should see a relative difference that is less than 1e-9.
#
# <div class="alert alert-box alert-success">
# **Practical Tip**: When performing gradient checking, it is much more efficient to use a small neural network with a relatively small number of input units and hidden units, thus having a relatively small number
# of parameters. Each dimension of $\theta$ requires two evaluations of the cost function and this can be expensive. In the function `checkNNGradients`, our code creates a small random model and dataset which is used with `computeNumericalGradient` for gradient checking. Furthermore, after you are confident that your gradient computations are correct, you should turn off gradient checking before running your learning algorithm.
# </div>
#
# <div class="alert alert-box alert-success">
#     <b>Practical Tip:</b> Gradient checking works for any function where you are computing the cost and the gradient. Concretely, you can use the same `computeNumericalGradient` function to check if your gradient implementations for the other exercises are correct too (e.g., logistic regression’s cost function).
# </div>

# %%
checkNNGradients(nnCostFunction)
# Out:
# [[-9.27825235e-03 -9.27825236e-03]
#  [-3.04978709e-06 -3.04978914e-06]
#  [-1.75060082e-04 -1.75060082e-04]
#  [-9.62660618e-05 -9.62660620e-05]
#  [ 8.89911959e-03  8.89911960e-03]
#  [ 1.42869427e-05  1.42869443e-05]
#  [ 2.33146358e-04  2.33146357e-04]
#  [ 1.17982666e-04  1.17982666e-04]
#  [-8.36010761e-03 -8.36010762e-03]
#  [-2.59383071e-05 -2.59383100e-05]
#  [-2.87468729e-04 -2.87468729e-04]
#  [-1.37149709e-04 -1.37149706e-04]
#  [ 7.62813551e-03  7.62813551e-03]
#  [ 3.69883213e-05  3.69883234e-05]
#  [ 3.35320349e-04  3.35320347e-04]
#  [ 1.53247077e-04  1.53247082e-04]
#  [-6.74798369e-03 -6.74798370e-03]
#  [-4.68759764e-05 -4.68759769e-05]
#  [-3.76215585e-04 -3.76215587e-04]
#  [-1.66560294e-04 -1.66560294e-04]
#  [ 3.14544970e-01  3.14544970e-01]
#  [ 1.64090819e-01  1.64090819e-01]
#  [ 1.64567932e-01  1.64567932e-01]
#  [ 1.58339334e-01  1.58339334e-01]
#  [ 1.51127527e-01  1.51127527e-01]
#  [ 1.49568335e-01  1.49568335e-01]
#  [ 1.11056588e-01  1.11056588e-01]
#  [ 5.75736493e-02  5.75736493e-02]
#  [ 5.77867378e-02  5.77867378e-02]
#  [ 5.59235296e-02  5.59235296e-02]
#  [ 5.36967009e-02  5.36967009e-02]
#  [ 5.31542052e-02  5.31542052e-02]
#  [ 9.74006970e-02  9.74006970e-02]
#  [ 5.04575855e-02  5.04575855e-02]
#  [ 5.07530173e-02  5.07530173e-02]
#  [ 4.91620841e-02  4.91620841e-02]
#  [ 4.71456249e-02  4.71456249e-02]
#  [ 4.65597186e-02  4.65597186e-02]]
# The above two columns you get should be very similar.
# (Left-Your Numerical Gradient, Right-Analytical Gradient)
#
# If your backpropagation implementation is correct, then
# the relative difference will be small (less than 1e-9).
# Relative Difference: 2.48422e-11

# %% [markdown]
# <a id="section5"></a>
#
# ### 2.5 Regularized Neural Network
#
# After you have successfully implemented the backpropagation algorithm, you will add regularization to the gradient. To account for regularization, it turns out that you can add this as an additional term _after_ computing the gradients using backpropagation.
#
# Specifically, after you have computed $\Delta_{ij}^{(l)}$ using backpropagation, you should add regularization using
#
# $$
# \begin{align}
# & \frac{\partial}{\partial \Theta_{ij}^{(l)}} J(\Theta) = D_{ij}^{(l)} = \frac{1}{m} \Delta_{ij}^{(l)} & \qquad \text{for } j = 0 \\
# & \frac{\partial}{\partial \Theta_{ij}^{(l)}} J(\Theta) = D_{ij}^{(l)} = \frac{1}{m} \Delta_{ij}^{(l)} + \frac{\lambda}{m} \Theta_{ij}^{(l)} & \qquad \text{for } j \ge 1
# \end{align}
# $$
#
# Note that you should _not_ be regularizing the first column of $\Theta^{(l)}$ which is used for the bias term. Furthermore, in the parameters $\Theta_{ij}^{(l)}$, $i$ is indexed starting from 1, and $j$ is indexed starting from 0. Thus,
#
# $$
# \Theta^{(l)} = \begin{bmatrix}
# \Theta_{1,0}^{(i)} & \Theta_{1,1}^{(l)} & \cdots \\
# \Theta_{2,0}^{(i)} & \Theta_{2,1}^{(l)} & \cdots \\
# \vdots &  ~ & \ddots
# \end{bmatrix}
# $$
#
# [Now modify your code that computes grad in `nnCostFunction` to account for regularization.](#nnCostFunction)
#
# After you are done, the following cell runs gradient checking on your implementation. If your code is correct, you should expect to see a relative difference that is less than 1e-9.

# %%
#  Check gradients by running checkNNGradients
lambda_ = 3
checkNNGradients(nnCostFunction, lambda_)

# Also output the costFunction debugging values
debug_J, _  = nnCostFunction(nn_params, input_layer_size,
                          hidden_layer_size, num_labels, X, y, lambda_)

print('\n\nCost at (fixed) debugging parameters (w/ lambda = %f): %f ' % (lambda_, debug_J))
print('(for lambda = 3, this value should be about 0.576051)')
# Out:
# [[-9.27825235e-03 -9.27825236e-03]
#  [-1.67679797e-02 -1.67679797e-02]
#  [-6.01744725e-02 -6.01744725e-02]
#  [-1.73704651e-02 -1.73704651e-02]
#  [ 8.89911959e-03  8.89911960e-03]
#  [ 3.94334829e-02  3.94334829e-02]
#  [-3.19612287e-02 -3.19612287e-02]
#  [-5.75658668e-02 -5.75658668e-02]
#  [-8.36010761e-03 -8.36010762e-03]
#  [ 5.93355565e-02  5.93355565e-02]
#  [ 2.49225535e-02  2.49225535e-02]
#  [-4.51963845e-02 -4.51963845e-02]
#  [ 7.62813551e-03  7.62813551e-03]
#  [ 2.47640974e-02  2.47640974e-02]
#  [ 5.97717617e-02  5.97717617e-02]
#  [ 9.14587966e-03  9.14587966e-03]
#  [-6.74798369e-03 -6.74798370e-03]
#  [-3.26881426e-02 -3.26881426e-02]
#  [ 3.86410548e-02  3.86410548e-02]
#  [ 5.46101547e-02  5.46101547e-02]
#  [ 3.14544970e-01  3.14544970e-01]
#  [ 1.18682669e-01  1.18682669e-01]
#  [ 2.03987128e-01  2.03987128e-01]
#  [ 1.25698067e-01  1.25698067e-01]
#  [ 1.76337550e-01  1.76337550e-01]
#  [ 1.32294136e-01  1.32294136e-01]
#  [ 1.11056588e-01  1.11056588e-01]
#  [ 3.81928666e-05  3.81928696e-05]
#  [ 1.17148233e-01  1.17148233e-01]
#  [-4.07588279e-03 -4.07588279e-03]
#  [ 1.13133142e-01  1.13133142e-01]
#  [-4.52964427e-03 -4.52964427e-03]
#  [ 9.74006970e-02  9.74006970e-02]
#  [ 3.36926556e-02  3.36926556e-02]
#  [ 7.54801264e-02  7.54801264e-02]
#  [ 1.69677090e-02  1.69677090e-02]
#  [ 8.61628953e-02  8.61628953e-02]
#  [ 1.50048382e-03  1.50048382e-03]]
# The above two columns you get should be very similar.
# (Left-Your Numerical Gradient, Right-Analytical Gradient)
#
# If your backpropagation implementation is correct, then
# the relative difference will be small (less than 1e-9).
# Relative Difference: 2.4094e-11
#
#
# Cost at (fixed) debugging parameters (w/ lambda = 3.000000): 0.576051
# (for lambda = 3, this value should be about 0.576051)

# %% [markdown]
# ### 2.6 Learning parameters using `scipy.optimize.minimize`
#
# After you have successfully implemented the neural network cost function
# and gradient computation, the next step we will use `scipy`'s minimization to learn a good set parameters.

# %%
def learn_weights(maxiter=100, method="TNC", lambda_= 1 ):
    
    #  After you have completed the assignment, change the maxiter to a larger
    #  value to see how more training helps.
    options= {'maxiter': maxiter}
   

    # Create "short hand" for the cost function to be minimized
    costFunction = lambda p: nnCostFunction(p, input_layer_size,
                                            hidden_layer_size,
                                            num_labels, X, y, lambda_)

    # Now, costFunction is a function that takes in only one argument
    # (the neural network parameters)
    res = optimize.minimize(costFunction,
                            initial_nn_params,
                            jac=True,
                            method=method,
                            options=options)

    # get the solution of the optimization
    nn_params = res.x
            
    # Obtain Theta1 and Theta2 back from nn_params
    Theta1 = np.reshape(nn_params[:hidden_layer_size * (input_layer_size + 1)],
                        (hidden_layer_size, (input_layer_size + 1)))

    Theta2 = np.reshape(nn_params[(hidden_layer_size * (input_layer_size + 1)):],
                        (num_labels, (hidden_layer_size + 1)))
    
    return Theta1, Theta2

Theta1, Theta2 = learn_weights()

# %% [markdown]
# After the training completes, we will proceed to report the training accuracy of your classifier by computing the percentage of examples it got correct. If your implementation is correct, you should see a reported
# training accuracy of about 95.3% (this may vary by about 1% due to the random initialization). It is possible to get higher training accuracies by training the neural network for more iterations. We encourage you to try
# training the neural network for more iterations (e.g., set `maxiter` to 400) and also vary the regularization parameter $\lambda$. With the right learning settings, it is possible to get the neural network to perfectly fit the training set.

# %%
def predict_train_set():

    pred = predict(Theta1, Theta2, X)
    acc = (np.mean(pred == y) * 100)
    f1 = metrics.f1_score(y, pred, average="macro")

    return acc,f1

def predict_test_set(x_test, y_test):

    pred = predict(Theta1, Theta2, x_test)
    acc = (np.mean(pred == y_test) * 100)
    f1 = metrics.f1_score(y_test, pred, average="macro")

    return acc,f1

acc, f1= predict_train_set()

print('Training Set Accuracy: %.2f%%' % acc)
print('Training Set F1: %.2f' % f1)
# Out:
# Training Set Accuracy: 96.48%
# Training Set F1: 0.96

# %% [markdown]
# ## 3 Visualizing the Hidden Layer
#
# One way to understand what your neural network is learning is to visualize what the representations captured by the hidden units. Informally, given a particular hidden unit, one way to visualize what it computes is to find an input $x$ that will cause it to activate (that is, to have an activation value
# ($a_i^{(l)}$) close to 1). For the neural network you trained, notice that the $i^{th}$ row of $\Theta^{(1)}$ is a 401-dimensional vector that represents the parameter for the $i^{th}$ hidden unit. If we discard the bias term, we get a 400 dimensional vector that represents the weights from each input pixel to the hidden unit.
#
# Thus, one way to visualize the “representation” captured by the hidden unit is to reshape this 400 dimensional vector into a 20 × 20 image and display it (It turns out that this is equivalent to finding the input that gives the highest activation for the hidden unit, given a “norm” constraint on the input (i.e., $||x||_2 \le 1$)).
#
# The next cell does this by using the `displayData` function and it will show you an image with 25 units,
# each corresponding to one hidden unit in the network. In your trained network, you should find that the hidden units corresponds roughly to detectors that look for strokes and other patterns in the input.

# %%
displayData(Theta1[:, 1:])

# %% [markdown]
# ### 3.1 Optional (ungraded) exercise
#
# In this part of the exercise, you will get to try out different learning settings for the neural network to see how the performance of the neural network varies with the regularization parameter $\lambda$ and number of training steps (the `maxiter` option when using `scipy.optimize.minimize`). Neural networks are very powerful models that can form highly complex decision boundaries. Without regularization, it is possible for a neural network to “overfit” a training set so that it obtains close to 100% accuracy on the training set but does not as well on new examples that it has not seen before. You can set the regularization $\lambda$ to a smaller value and the `maxiter` parameter to a higher number of iterations to see this for youself.

# %% [markdown]
# <a id="report"></a>
#
# # IAC Report for Ex 4
#
# In the following steps, we will analyze the implementation of backpropagation from exercise 4.
# We will check the influence of the regularization term ($\lambda$), optimization methods (TNC, L-BFGS-B, ...), and training steps influence the final accuracy on train set.
# We also would like to test values for learning rate, but the `scipy.optimize` method does not support this parameter.
#
# We intend to run some experiments.
#
# - Test multiple optimization methods (TNC, L-BFGS-B)
# - Test multiple regularization terms (from $0.01$ to $10$)
# - Test maximum interations (from $64$ to $1024$)
#
# # Experiments
#
# We start by reloading the dataset and splitting it into train and test set (80-20%), so we do not interfere in the previous code from this assignment.
#
#
# The neural network continues with the same architecture.

# %%
from sklearn.model_selection import train_test_split

#  training data stored in arrays X, y
data = loadmat("Data/ex4data1.mat")
#data = loadmat('/MyDrive/os.path.join('Data', 'ex4data1.mat'))
X, y = data['X'], data['y'].ravel()

# set the zero digit to 0, rather than its mapped 10 in this dataset
# This is an artifact due to the fact that this dataset was used in 
# MATLAB where there is no index 0
y[y == 10] = 0

# Train test split
# Obs: we named the train variables with the same name as before to avoid inconsistencies.
X, X_test, y, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, stratify=y, random_state=42)

# Number of training examples
m = y.size

# Setup the parameters you will use for this exercise
input_layer_size  = 400  # 20x20 Input Images of Digits
hidden_layer_size = 25   # 25 hidden units
num_labels = 10          # 10 labels, from 0 to 9

# %%
methods_list = ["TNC", "L-BFGS-B"]
data = []
num_repetitions = 5
num_iters_list = [64, 128, 256, 512, 1024]
hidden_layer_list = [4,8,16,25,64,128,512]
lambda_list = [0, 0.01, 0.1, 1, 3, 5]

# %%
# Iterate through method list
for hidden_layer_size in hidden_layer_list:
    for method in methods_list:
        for num_iter in num_iters_list:
            for lambda_ in lambda_list:

                # Test value of lambda
                print("=== Training network (hidden layer: %d, method: %s; num_iter: %d; lambda:%.2f) ===" % (hidden_layer_size, method, num_iter, lambda_))
                
                accs = []
                accs_test = []
                train_time = []
                f1s = []
                
                #
                # Due to randomness, we repeat train N networks to get more precise metrics
                #
                for repetition in range(num_repetitions):
                    print(".", end="")

                    # Store initial time to check training time in seconds
                    t1 = time.time()
                    initial_nn_params = initializeParams()
                    Theta1, Theta2 = learn_weights(maxiter=num_iter, method=method, lambda_= lambda_)
                    acc, f1 = predict_train_set()
                    acc_test, f1_test = predict_test_set(X_test, y_test)
                    t2 = time.time()

                    accs.append(acc)
                    train_time.append(t2-t1)
                    accs_test.append(acc_test)


                print("\nAcc (Train): %.1f (±%.1f) | Acc (Test):  %.1f (±%.1f) | Train time: %.2f (±%.2f)" % (np.mean(accs), np.std(accs), np.mean(accs_test), np.std(accs_test), np.mean(train_time), np.std(train_time)))

                data.append(
                    [
                        hidden_layer_size,
                        method,
                        num_iter,
                        lambda_,
                        np.mean(accs), np.std(accs),
                        np.mean(accs_test), np.std(accs_test),
                        np.mean(train_time), np.std(train_time)
                    ]
                )

df = pd.DataFrame(data, columns=[
    "Hidden Layer", "Method", "Num_Inter", "lambda_",
    "Acc mean", "Acc std",
    "Acc test mean", "Acc test std",
    "Train time mean", "Train time std"
])
df.to_excel("report/method_results.xlsx", index=False)
# Out:
# === Training network (hidden layer: 4, method: TNC; num_iter: 64; lambda:0.00) ===
# .....
# Acc (Train): 55.7 (±16.8) | Acc (Test):  53.8 (±16.0) | Train time: 0.59 (±0.02)
# === Training network (hidden layer: 4, method: TNC; num_iter: 64; lambda:0.01) ===
# .....
# Acc (Train): 60.7 (±5.0) | Acc (Test):  60.3 (±5.2) | Train time: 0.57 (±0.01)
# === Training network (hidden layer: 4, method: TNC; num_iter: 64; lambda:0.10) ===
# .....
# Acc (Train): 63.7 (±6.2) | Acc (Test):  63.7 (±6.4) | Train time: 0.57 (±0.01)
# === Training network (hidden layer: 4, method: TNC; num_iter: 64; lambda:1.00) ===
# .....
# Acc (Train): 60.0 (±8.8) | Acc (Test):  59.8 (±8.2) | Train time: 0.59 (±0.03)
# === Training network (hidden layer: 4, method: TNC; num_iter: 64; lambda:3.00) ===
# .....
# Acc (Train): 68.0 (±4.8) | Acc (Test):  67.0 (±3.3) | Train time: 0.61 (±0.02)
# === Training network (hidden layer: 4, method: TNC; num_iter: 64; lambda:5.00) ===
# .....
# Acc (Train): 55.4 (±14.3) | Acc (Test):  54.6 (±13.7) | Train time: 0.58 (±0.02)
# === Training network (hidden layer: 4, method: TNC; num_iter: 128; lambda:0.00) ===
# .....
# Acc (Train): 81.1 (±5.5) | Acc (Test):  77.2 (±4.8) | Train time: 1.11 (±0.04)
# === Training network (hidden layer: 4, method: TNC; num_iter: 128; lambda:0.01) ===
# .....
# Acc (Train): 79.3 (±5.9) | Acc (Test):  74.9 (±5.3) | Train time: 1.09 (±0.02)
# === Training network (hidden layer: 4, method: TNC; num_iter: 128; lambda:0.10) ===
# .....
# Acc (Train): 76.0 (±7.6) | Acc (Test):  71.2 (±6.9) | Train time: 1.10 (±0.02)
# === Training network (hidden layer: 4, method: TNC; num_iter: 128; lambda:1.00) ===
# .....
# Acc (Train): 83.8 (±2.6) | Acc (Test):  79.8 (±3.2) | Train time: 1.10 (±0.02)
# === Training network (hidden layer: 4, method: TNC; num_iter: 128; lambda:3.00) ===
# .....
# Acc (Train): 81.6 (±4.0) | Acc (Test):  78.0 (±3.3) | Train time: 1.09 (±0.01)
# === Training network (hidden layer: 4, method: TNC; num_iter: 128; lambda:5.00) ===
# .....
# Acc (Train): 80.7 (±5.5) | Acc (Test):  78.0 (±3.9) | Train time: 1.09 (±0.01)
# === Training network (hidden layer: 4, method: TNC; num_iter: 256; lambda:0.00) ===
# .....
# Acc (Train): 87.2 (±4.1) | Acc (Test):  80.1 (±3.4) | Train time: 2.30 (±0.18)
# === Training network (hidden layer: 4, method: TNC; num_iter: 256; lambda:0.01) ===
# .....
# Acc (Train): 83.9 (±5.5) | Acc (Test):  76.6 (±5.4) | Train time: 2.24 (±0.16)
# === Training network (hidden layer: 4, method: TNC; num_iter: 256; lambda:0.10) ===
# .....
# Acc (Train): 85.4 (±0.8) | Acc (Test):  77.8 (±0.8) | Train time: 2.15 (±0.01)
# === Training network (hidden layer: 4, method: TNC; num_iter: 256; lambda:1.00) ===
# .....
# Acc (Train): 86.4 (±4.2) | Acc (Test):  80.4 (±3.4) | Train time: 2.19 (±0.02)
# === Training network (hidden layer: 4, method: TNC; num_iter: 256; lambda:3.00) ===
# .....
# Acc (Train): 87.2 (±1.5) | Acc (Test):  83.0 (±2.0) | Train time: 2.24 (±0.05)
# === Training network (hidden layer: 4, method: TNC; num_iter: 256; lambda:5.00) ===
# .....
# Acc (Train): 83.4 (±3.6) | Acc (Test):  79.9 (±3.3) | Train time: 2.43 (±0.07)
# === Training network (hidden layer: 4, method: TNC; num_iter: 512; lambda:0.00) ===
# .....
# Acc (Train): 82.3 (±13.5) | Acc (Test):  70.6 (±8.3) | Train time: 4.81 (±0.16)
# === Training network (hidden layer: 4, method: TNC; num_iter: 512; lambda:0.01) ===
# .....
# Acc (Train): 85.2 (±7.3) | Acc (Test):  74.6 (±3.6) | Train time: 4.06 (±0.74)
# === Training network (hidden layer: 4, method: TNC; num_iter: 512; lambda:0.10) ===
# .....
# Acc (Train): 88.1 (±6.8) | Acc (Test):  77.8 (±4.3) | Train time: 4.10 (±0.46)
# === Training network (hidden layer: 4, method: TNC; num_iter: 512; lambda:1.00) ===
# .....
# Acc (Train): 89.8 (±0.8) | Acc (Test):  82.2 (±1.3) | Train time: 4.19 (±0.03)
# === Training network (hidden layer: 4, method: TNC; num_iter: 512; lambda:3.00) ===
# .....
# Acc (Train): 88.7 (±0.8) | Acc (Test):  83.9 (±0.9) | Train time: 4.17 (±0.13)
# === Training network (hidden layer: 4, method: TNC; num_iter: 512; lambda:5.00) ===
# .....
# Acc (Train): 86.7 (±1.0) | Acc (Test):  83.5 (±0.9) | Train time: 3.81 (±0.42)
# === Training network (hidden layer: 4, method: TNC; num_iter: 1024; lambda:0.00) ===
# .....
# Acc (Train): 88.4 (±5.6) | Acc (Test):  74.0 (±1.8) | Train time: 7.51 (±2.35)
# === Training network (hidden layer: 4, method: TNC; num_iter: 1024; lambda:0.01) ===
# .....
# Acc (Train): 92.8 (±1.9) | Acc (Test):  78.2 (±1.5) | Train time: 6.34 (±1.70)
# === Training network (hidden layer: 4, method: TNC; num_iter: 1024; lambda:0.10) ===
# .....
# Acc (Train): 88.5 (±2.0) | Acc (Test):  78.4 (±1.8) | Train time: 7.75 (±2.63)
# === Training network (hidden layer: 4, method: TNC; num_iter: 1024; lambda:1.00) ===
# .....
# Acc (Train): 89.4 (±3.7) | Acc (Test):  83.8 (±2.7) | Train time: 5.95 (±1.98)
# === Training network (hidden layer: 4, method: TNC; num_iter: 1024; lambda:3.00) ===
# .....
# Acc (Train): 89.0 (±0.7) | Acc (Test):  83.7 (±1.5) | Train time: 5.32 (±1.85)
# === Training network (hidden layer: 4, method: TNC; num_iter: 1024; lambda:5.00) ===
# .....
# Acc (Train): 87.4 (±1.0) | Acc (Test):  84.1 (±1.3) | Train time: 4.08 (±0.67)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 64; lambda:0.00) ===
# .....
# Acc (Train): 76.8 (±7.0) | Acc (Test):  71.7 (±6.3) | Train time: 0.66 (±0.03)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 64; lambda:0.01) ===
# .....
# Acc (Train): 75.1 (±5.9) | Acc (Test):  71.6 (±4.7) | Train time: 0.63 (±0.02)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 64; lambda:0.10) ===
# .....
# Acc (Train): 73.2 (±11.5) | Acc (Test):  69.6 (±9.4) | Train time: 0.62 (±0.01)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 64; lambda:1.00) ===
# .....
# Acc (Train): 82.1 (±3.4) | Acc (Test):  78.5 (±3.7) | Train time: 0.65 (±0.03)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 64; lambda:3.00) ===
# .....
# Acc (Train): 81.7 (±2.0) | Acc (Test):  77.8 (±2.2) | Train time: 0.65 (±0.03)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 64; lambda:5.00) ===
# .....
# Acc (Train): 81.0 (±3.0) | Acc (Test):  78.3 (±2.4) | Train time: 0.65 (±0.01)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 128; lambda:0.00) ===
# .....
# Acc (Train): 82.6 (±4.7) | Acc (Test):  74.9 (±2.5) | Train time: 1.19 (±0.03)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 128; lambda:0.01) ===
# .....
# Acc (Train): 78.6 (±6.1) | Acc (Test):  71.6 (±5.9) | Train time: 1.28 (±0.12)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 128; lambda:0.10) ===
# .....
# Acc (Train): 82.1 (±3.8) | Acc (Test):  75.7 (±2.7) | Train time: 1.25 (±0.02)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 128; lambda:1.00) ===
# .....
# Acc (Train): 85.0 (±3.4) | Acc (Test):  79.1 (±4.6) | Train time: 1.32 (±0.09)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 128; lambda:3.00) ===
# .....
# Acc (Train): 86.7 (±2.0) | Acc (Test):  82.0 (±1.5) | Train time: 1.29 (±0.05)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 128; lambda:5.00) ===
# .....
# Acc (Train): 87.2 (±1.3) | Acc (Test):  83.6 (±1.2) | Train time: 1.26 (±0.04)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 256; lambda:0.00) ===
# .....
# Acc (Train): 88.3 (±3.6) | Acc (Test):  76.5 (±1.3) | Train time: 2.44 (±0.05)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 256; lambda:0.01) ===
# .....
# Acc (Train): 82.1 (±5.5) | Acc (Test):  72.6 (±5.4) | Train time: 2.36 (±0.04)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 256; lambda:0.10) ===
# .....
# Acc (Train): 87.8 (±5.7) | Acc (Test):  77.2 (±4.8) | Train time: 2.55 (±0.14)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 256; lambda:1.00) ===
# .....
# Acc (Train): 86.3 (±3.9) | Acc (Test):  80.4 (±2.0) | Train time: 2.67 (±0.21)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 256; lambda:3.00) ===
# .....
# Acc (Train): 87.2 (±1.5) | Acc (Test):  83.1 (±1.8) | Train time: 2.50 (±0.06)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 256; lambda:5.00) ===
# .....
# Acc (Train): 84.4 (±5.2) | Acc (Test):  81.3 (±4.8) | Train time: 2.51 (±0.07)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 512; lambda:0.00) ===
# .....
# Acc (Train): 88.8 (±3.7) | Acc (Test):  76.9 (±2.5) | Train time: 5.12 (±0.13)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 512; lambda:0.01) ===
# .....
# Acc (Train): 87.2 (±5.6) | Acc (Test):  73.9 (±4.9) | Train time: 5.09 (±0.15)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 512; lambda:0.10) ===
# .....
# Acc (Train): 87.3 (±5.1) | Acc (Test):  75.9 (±4.5) | Train time: 4.91 (±0.18)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 512; lambda:1.00) ===
# .....
# Acc (Train): 89.3 (±1.3) | Acc (Test):  82.1 (±1.7) | Train time: 5.00 (±0.14)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 512; lambda:3.00) ===
# .....
# Acc (Train): 87.7 (±1.0) | Acc (Test):  83.0 (±0.6) | Train time: 4.40 (±0.53)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 512; lambda:5.00) ===
# .....
# Acc (Train): 86.9 (±0.6) | Acc (Test):  84.2 (±1.3) | Train time: 3.86 (±1.47)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 1024; lambda:0.00) ===
# .....
# Acc (Train): 91.2 (±4.6) | Acc (Test):  76.2 (±3.1) | Train time: 10.76 (±0.21)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 1024; lambda:0.01) ===
# .....
# Acc (Train): 94.2 (±0.4) | Acc (Test):  80.2 (±0.4) | Train time: 11.05 (±0.29)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 1024; lambda:0.10) ===
# .....
# Acc (Train): 88.5 (±4.3) | Acc (Test):  76.1 (±3.7) | Train time: 10.78 (±0.20)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 1024; lambda:1.00) ===
# .....
# Acc (Train): 90.3 (±0.9) | Acc (Test):  83.5 (±1.4) | Train time: 8.21 (±1.91)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 1024; lambda:3.00) ===
# .....
# Acc (Train): 87.8 (±1.1) | Acc (Test):  83.9 (±1.0) | Train time: 6.00 (±2.19)
# === Training network (hidden layer: 4, method: L-BFGS-B; num_iter: 1024; lambda:5.00) ===
# .....
# Acc (Train): 86.9 (±0.8) | Acc (Test):  83.4 (±1.1) | Train time: 3.82 (±2.01)
# === Training network (hidden layer: 8, method: TNC; num_iter: 64; lambda:0.00) ===
# .....
# Acc (Train): 83.1 (±3.6) | Acc (Test):  81.5 (±3.0) | Train time: 0.68 (±0.01)
# === Training network (hidden layer: 8, method: TNC; num_iter: 64; lambda:0.01) ===
# .....
# Acc (Train): 85.7 (±3.7) | Acc (Test):  83.8 (±3.4) | Train time: 0.67 (±0.02)
# === Training network (hidden layer: 8, method: TNC; num_iter: 64; lambda:0.10) ===
# .....
# Acc (Train): 71.6 (±28.6) | Acc (Test):  70.6 (±28.5) | Train time: 0.69 (±0.03)
# === Training network (hidden layer: 8, method: TNC; num_iter: 64; lambda:1.00) ===
# .....
# Acc (Train): 86.5 (±1.6) | Acc (Test):  85.3 (±2.1) | Train time: 0.69 (±0.02)
# === Training network (hidden layer: 8, method: TNC; num_iter: 64; lambda:3.00) ===
# .....
# Acc (Train): 86.4 (±1.5) | Acc (Test):  84.7 (±2.0) | Train time: 0.67 (±0.02)
# === Training network (hidden layer: 8, method: TNC; num_iter: 64; lambda:5.00) ===
# .....
# Acc (Train): 83.8 (±3.2) | Acc (Test):  82.3 (±2.9) | Train time: 0.67 (±0.02)
# === Training network (hidden layer: 8, method: TNC; num_iter: 128; lambda:0.00) ===
# .....
# Acc (Train): 93.1 (±1.0) | Acc (Test):  87.2 (±0.5) | Train time: 1.38 (±0.02)
# === Training network (hidden layer: 8, method: TNC; num_iter: 128; lambda:0.01) ===
# .....
# Acc (Train): 92.0 (±2.0) | Acc (Test):  87.4 (±1.2) | Train time: 1.43 (±0.07)
# === Training network (hidden layer: 8, method: TNC; num_iter: 128; lambda:0.10) ===
# .....
# Acc (Train): 92.9 (±1.3) | Acc (Test):  88.1 (±0.8) | Train time: 1.40 (±0.06)
# === Training network (hidden layer: 8, method: TNC; num_iter: 128; lambda:1.00) ===
# .....
# Acc (Train): 94.3 (±0.8) | Acc (Test):  89.6 (±0.7) | Train time: 1.43 (±0.04)
# === Training network (hidden layer: 8, method: TNC; num_iter: 128; lambda:3.00) ===
# .....
# Acc (Train): 93.4 (±0.5) | Acc (Test):  89.6 (±0.4) | Train time: 1.38 (±0.03)
# === Training network (hidden layer: 8, method: TNC; num_iter: 128; lambda:5.00) ===
# .....
# Acc (Train): 91.1 (±2.0) | Acc (Test):  88.4 (±2.4) | Train time: 1.47 (±0.07)
# === Training network (hidden layer: 8, method: TNC; num_iter: 256; lambda:0.00) ===
# .....
# Acc (Train): 97.8 (±0.3) | Acc (Test):  87.3 (±0.7) | Train time: 3.00 (±0.11)
# === Training network (hidden layer: 8, method: TNC; num_iter: 256; lambda:0.01) ===
# .....
# Acc (Train): 97.4 (±0.9) | Acc (Test):  88.1 (±0.8) | Train time: 2.83 (±0.05)
# === Training network (hidden layer: 8, method: TNC; num_iter: 256; lambda:0.10) ===
# .....
# Acc (Train): 97.5 (±1.0) | Acc (Test):  87.3 (±1.3) | Train time: 3.01 (±0.09)
# === Training network (hidden layer: 8, method: TNC; num_iter: 256; lambda:1.00) ===
# .....
# Acc (Train): 96.8 (±0.3) | Acc (Test):  90.4 (±0.6) | Train time: 2.95 (±0.11)
# === Training network (hidden layer: 8, method: TNC; num_iter: 256; lambda:3.00) ===
# .....
# Acc (Train): 95.2 (±0.2) | Acc (Test):  91.0 (±0.4) | Train time: 2.88 (±0.15)
# === Training network (hidden layer: 8, method: TNC; num_iter: 256; lambda:5.00) ===
# .....
# Acc (Train): 93.8 (±0.3) | Acc (Test):  90.5 (±0.5) | Train time: 2.74 (±0.14)
# === Training network (hidden layer: 8, method: TNC; num_iter: 512; lambda:0.00) ===
# .....
# Acc (Train): 97.9 (±0.7) | Acc (Test):  86.8 (±1.1) | Train time: 4.45 (±0.32)
# === Training network (hidden layer: 8, method: TNC; num_iter: 512; lambda:0.01) ===
# .....
# Acc (Train): 98.5 (±0.5) | Acc (Test):  86.6 (±0.5) | Train time: 4.81 (±0.42)
# === Training network (hidden layer: 8, method: TNC; num_iter: 512; lambda:0.10) ===
# .....
# Acc (Train): 97.4 (±1.6) | Acc (Test):  87.6 (±0.6) | Train time: 4.70 (±0.76)
# === Training network (hidden layer: 8, method: TNC; num_iter: 512; lambda:1.00) ===
# .....
# Acc (Train): 97.3 (±0.2) | Acc (Test):  90.7 (±0.6) | Train time: 5.39 (±0.38)
# === Training network (hidden layer: 8, method: TNC; num_iter: 512; lambda:3.00) ===
# .....
# Acc (Train): 95.1 (±0.2) | Acc (Test):  91.0 (±0.2) | Train time: 5.52 (±0.11)
# === Training network (hidden layer: 8, method: TNC; num_iter: 512; lambda:5.00) ===
# .....
# Acc (Train): 94.0 (±0.4) | Acc (Test):  90.8 (±0.5) | Train time: 5.48 (±0.05)
# === Training network (hidden layer: 8, method: TNC; num_iter: 1024; lambda:0.00) ===
# .....
# Acc (Train): 97.6 (±1.6) | Acc (Test):  85.7 (±1.4) | Train time: 4.56 (±0.55)
# === Training network (hidden layer: 8, method: TNC; num_iter: 1024; lambda:0.01) ===
# .....
# Acc (Train): 98.2 (±0.7) | Acc (Test):  85.5 (±1.8) | Train time: 5.36 (±1.01)
# === Training network (hidden layer: 8, method: TNC; num_iter: 1024; lambda:0.10) ===
# .....
# Acc (Train): 98.6 (±0.5) | Acc (Test):  88.0 (±0.4) | Train time: 5.67 (±1.71)
# === Training network (hidden layer: 8, method: TNC; num_iter: 1024; lambda:1.00) ===
# .....
# Acc (Train): 97.7 (±0.2) | Acc (Test):  90.9 (±0.4) | Train time: 11.17 (±0.23)
# === Training network (hidden layer: 8, method: TNC; num_iter: 1024; lambda:3.00) ===
# .....
# Acc (Train): 95.0 (±0.4) | Acc (Test):  90.8 (±0.4) | Train time: 8.45 (±2.72)
# === Training network (hidden layer: 8, method: TNC; num_iter: 1024; lambda:5.00) ===
# .....
# Acc (Train): 94.2 (±0.3) | Acc (Test):  91.0 (±0.4) | Train time: 9.28 (±1.14)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 64; lambda:0.00) ===
# .....
# Acc (Train): 93.6 (±0.5) | Acc (Test):  87.2 (±0.5) | Train time: 0.82 (±0.03)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 64; lambda:0.01) ===
# .....
# Acc (Train): 93.6 (±1.3) | Acc (Test):  87.6 (±1.6) | Train time: 0.80 (±0.01)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 64; lambda:0.10) ===
# .....
# Acc (Train): 93.5 (±0.7) | Acc (Test):  87.3 (±0.9) | Train time: 0.81 (±0.01)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 64; lambda:1.00) ===
# .....
# Acc (Train): 93.6 (±0.7) | Acc (Test):  88.5 (±0.7) | Train time: 0.80 (±0.04)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 64; lambda:3.00) ===
# .....
# Acc (Train): 93.6 (±0.4) | Acc (Test):  90.4 (±0.5) | Train time: 0.82 (±0.05)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 64; lambda:5.00) ===
# .....
# Acc (Train): 93.0 (±0.6) | Acc (Test):  90.1 (±1.0) | Train time: 0.77 (±0.02)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 128; lambda:0.00) ===
# .....
# Acc (Train): 96.2 (±0.4) | Acc (Test):  86.1 (±1.4) | Train time: 1.52 (±0.06)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 128; lambda:0.01) ===
# .....
# Acc (Train): 96.2 (±0.6) | Acc (Test):  86.4 (±1.0) | Train time: 1.46 (±0.04)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 128; lambda:0.10) ===
# .....
# Acc (Train): 96.6 (±0.4) | Acc (Test):  86.7 (±1.0) | Train time: 1.60 (±0.07)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 128; lambda:1.00) ===
# .....
# Acc (Train): 96.1 (±0.4) | Acc (Test):  89.7 (±0.8) | Train time: 1.53 (±0.05)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 128; lambda:3.00) ===
# .....
# Acc (Train): 94.6 (±0.4) | Acc (Test):  90.7 (±0.5) | Train time: 1.45 (±0.05)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 128; lambda:5.00) ===
# .....
# Acc (Train): 93.6 (±0.4) | Acc (Test):  90.2 (±0.5) | Train time: 1.55 (±0.09)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 256; lambda:0.00) ===
# .....
# Acc (Train): 97.3 (±0.7) | Acc (Test):  86.3 (±1.1) | Train time: 3.02 (±0.11)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 256; lambda:0.01) ===
# .....
# Acc (Train): 97.2 (±0.9) | Acc (Test):  85.9 (±1.1) | Train time: 2.97 (±0.08)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 256; lambda:0.10) ===
# .....
# Acc (Train): 98.3 (±0.3) | Acc (Test):  87.1 (±0.4) | Train time: 2.87 (±0.06)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 256; lambda:1.00) ===
# .....
# Acc (Train): 97.2 (±0.4) | Acc (Test):  90.5 (±0.8) | Train time: 3.07 (±0.16)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 256; lambda:3.00) ===
# .....
# Acc (Train): 94.9 (±0.2) | Acc (Test):  90.9 (±0.3) | Train time: 2.99 (±0.03)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 256; lambda:5.00) ===
# .....
# Acc (Train): 94.1 (±0.3) | Acc (Test):  90.8 (±0.2) | Train time: 2.83 (±0.08)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 512; lambda:0.00) ===
# .....
# Acc (Train): 98.3 (±0.5) | Acc (Test):  85.2 (±1.2) | Train time: 7.74 (±4.68)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 512; lambda:0.01) ===
# .....
# Acc (Train): 97.9 (±0.5) | Acc (Test):  84.3 (±0.9) | Train time: 5.35 (±0.17)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 512; lambda:0.10) ===
# .....
# Acc (Train): 98.7 (±0.3) | Acc (Test):  86.0 (±1.5) | Train time: 5.37 (±0.10)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 512; lambda:1.00) ===
# .....
# Acc (Train): 97.4 (±0.3) | Acc (Test):  90.7 (±0.4) | Train time: 5.30 (±0.10)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 512; lambda:3.00) ===
# .....
# Acc (Train): 95.4 (±0.1) | Acc (Test):  91.1 (±0.3) | Train time: 5.38 (±0.06)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 512; lambda:5.00) ===
# .....
# Acc (Train): 94.0 (±0.2) | Acc (Test):  90.9 (±0.2) | Train time: 4.80 (±0.85)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 1024; lambda:0.00) ===
# .....
# Acc (Train): 98.2 (±0.5) | Acc (Test):  84.0 (±0.9) | Train time: 20.93 (±11.00)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 1024; lambda:0.01) ===
# .....
# Acc (Train): 98.7 (±0.2) | Acc (Test):  85.3 (±0.8) | Train time: 17.46 (±13.37)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 1024; lambda:0.10) ===
# .....
# Acc (Train): 99.2 (±0.1) | Acc (Test):  87.1 (±1.5) | Train time: 10.78 (±0.16)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 1024; lambda:1.00) ===
# .....
# Acc (Train): 97.8 (±0.3) | Acc (Test):  90.9 (±0.4) | Train time: 10.24 (±0.31)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 1024; lambda:3.00) ===
# .....
# Acc (Train): 95.3 (±0.1) | Acc (Test):  91.0 (±0.5) | Train time: 7.31 (±1.49)
# === Training network (hidden layer: 8, method: L-BFGS-B; num_iter: 1024; lambda:5.00) ===
# .....
# Acc (Train): 94.0 (±0.3) | Acc (Test):  90.7 (±0.6) | Train time: 5.52 (±1.50)
# === Training network (hidden layer: 16, method: TNC; num_iter: 64; lambda:0.00) ===
# .....
# Acc (Train): 89.3 (±2.4) | Acc (Test):  87.5 (±2.0) | Train time: 0.73 (±0.03)
# === Training network (hidden layer: 16, method: TNC; num_iter: 64; lambda:0.01) ===
# .....
# Acc (Train): 90.8 (±1.3) | Acc (Test):  88.5 (±0.7) | Train time: 0.72 (±0.00)
# === Training network (hidden layer: 16, method: TNC; num_iter: 64; lambda:0.10) ===
# .....
# Acc (Train): 90.8 (±3.5) | Acc (Test):  88.6 (±3.2) | Train time: 0.72 (±0.02)
# === Training network (hidden layer: 16, method: TNC; num_iter: 64; lambda:1.00) ===
# .....
# Acc (Train): 91.7 (±1.0) | Acc (Test):  89.7 (±0.6) | Train time: 0.73 (±0.01)
# === Training network (hidden layer: 16, method: TNC; num_iter: 64; lambda:3.00) ===
# .....
# Acc (Train): 89.7 (±2.1) | Acc (Test):  87.8 (±1.7) | Train time: 0.74 (±0.04)
# === Training network (hidden layer: 16, method: TNC; num_iter: 64; lambda:5.00) ===
# .....
# Acc (Train): 89.4 (±0.8) | Acc (Test):  88.2 (±1.0) | Train time: 0.72 (±0.02)
# === Training network (hidden layer: 16, method: TNC; num_iter: 128; lambda:0.00) ===
# .....
# Acc (Train): 97.0 (±0.9) | Acc (Test):  91.3 (±0.6) | Train time: 1.42 (±0.02)
# === Training network (hidden layer: 16, method: TNC; num_iter: 128; lambda:0.01) ===
# .....
# Acc (Train): 96.1 (±0.9) | Acc (Test):  91.1 (±0.8) | Train time: 1.45 (±0.02)
# === Training network (hidden layer: 16, method: TNC; num_iter: 128; lambda:0.10) ===
# .....
# Acc (Train): 96.9 (±0.4) | Acc (Test):  91.9 (±1.0) | Train time: 1.41 (±0.01)
# === Training network (hidden layer: 16, method: TNC; num_iter: 128; lambda:1.00) ===
# .....
# Acc (Train): 96.6 (±0.8) | Acc (Test):  92.0 (±0.5) | Train time: 1.42 (±0.02)
# === Training network (hidden layer: 16, method: TNC; num_iter: 128; lambda:3.00) ===
# .....
# Acc (Train): 94.0 (±1.7) | Acc (Test):  91.2 (±1.0) | Train time: 1.42 (±0.01)
# === Training network (hidden layer: 16, method: TNC; num_iter: 128; lambda:5.00) ===
# .....
# Acc (Train): 94.0 (±0.9) | Acc (Test):  91.2 (±0.6) | Train time: 1.47 (±0.03)
# === Training network (hidden layer: 16, method: TNC; num_iter: 256; lambda:0.00) ===
# .....
# Acc (Train): 99.5 (±0.3) | Acc (Test):  89.9 (±0.9) | Train time: 3.07 (±0.13)
# === Training network (hidden layer: 16, method: TNC; num_iter: 256; lambda:0.01) ===
# .....
# Acc (Train): 99.7 (±0.2) | Acc (Test):  90.6 (±0.7) | Train time: 3.04 (±0.17)
# === Training network (hidden layer: 16, method: TNC; num_iter: 256; lambda:0.10) ===
# .....
# Acc (Train): 99.7 (±0.2) | Acc (Test):  91.6 (±0.5) | Train time: 3.20 (±0.45)
# === Training network (hidden layer: 16, method: TNC; num_iter: 256; lambda:1.00) ===
# .....
# Acc (Train): 98.9 (±0.1) | Acc (Test):  92.7 (±0.2) | Train time: 2.80 (±0.01)
# === Training network (hidden layer: 16, method: TNC; num_iter: 256; lambda:3.00) ===
# .....
# Acc (Train): 96.9 (±0.1) | Acc (Test):  92.4 (±0.3) | Train time: 2.83 (±0.03)
# === Training network (hidden layer: 16, method: TNC; num_iter: 256; lambda:5.00) ===
# .....
# Acc (Train): 95.2 (±0.3) | Acc (Test):  91.8 (±0.2) | Train time: 2.84 (±0.03)
# === Training network (hidden layer: 16, method: TNC; num_iter: 512; lambda:0.00) ===
# .....
# Acc (Train): 99.9 (±0.1) | Acc (Test):  90.5 (±0.6) | Train time: 4.77 (±0.27)
# === Training network (hidden layer: 16, method: TNC; num_iter: 512; lambda:0.01) ===
# .....
# Acc (Train): 99.8 (±0.3) | Acc (Test):  91.1 (±0.4) | Train time: 4.71 (±0.66)
# === Training network (hidden layer: 16, method: TNC; num_iter: 512; lambda:0.10) ===
# .....
# Acc (Train): 99.5 (±0.4) | Acc (Test):  91.5 (±0.6) | Train time: 4.79 (±0.67)
# === Training network (hidden layer: 16, method: TNC; num_iter: 512; lambda:1.00) ===
# .....
# Acc (Train): 99.0 (±0.4) | Acc (Test):  92.7 (±0.4) | Train time: 5.30 (±1.11)
# === Training network (hidden layer: 16, method: TNC; num_iter: 512; lambda:3.00) ===
# .....
# Acc (Train): 97.0 (±0.3) | Acc (Test):  92.7 (±0.2) | Train time: 5.26 (±0.89)
# === Training network (hidden layer: 16, method: TNC; num_iter: 512; lambda:5.00) ===
# .....
# Acc (Train): 95.5 (±0.2) | Acc (Test):  92.5 (±0.4) | Train time: 5.74 (±0.21)
# === Training network (hidden layer: 16, method: TNC; num_iter: 1024; lambda:0.00) ===
# .....
# Acc (Train): 99.8 (±0.1) | Acc (Test):  90.0 (±1.2) | Train time: 4.71 (±0.35)
# === Training network (hidden layer: 16, method: TNC; num_iter: 1024; lambda:0.01) ===
# .....
# Acc (Train): 99.9 (±0.1) | Acc (Test):  90.1 (±0.7) | Train time: 5.01 (±0.59)
# === Training network (hidden layer: 16, method: TNC; num_iter: 1024; lambda:0.10) ===
# .....
# Acc (Train): 99.7 (±0.4) | Acc (Test):  91.5 (±0.3) | Train time: 5.31 (±0.81)
# === Training network (hidden layer: 16, method: TNC; num_iter: 1024; lambda:1.00) ===
# .....
# Acc (Train): 99.3 (±0.0) | Acc (Test):  93.2 (±0.4) | Train time: 10.97 (±0.05)
# === Training network (hidden layer: 16, method: TNC; num_iter: 1024; lambda:3.00) ===
# .....
# Acc (Train): 97.1 (±0.1) | Acc (Test):  92.8 (±0.3) | Train time: 10.96 (±0.04)
# === Training network (hidden layer: 16, method: TNC; num_iter: 1024; lambda:5.00) ===
# .....
# Acc (Train): 95.6 (±0.1) | Acc (Test):  92.2 (±0.4) | Train time: 9.33 (±2.92)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 64; lambda:0.00) ===
# .....
# Acc (Train): 98.3 (±0.4) | Acc (Test):  90.6 (±0.8) | Train time: 0.76 (±0.03)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 64; lambda:0.01) ===
# .....
# Acc (Train): 97.7 (±0.5) | Acc (Test):  90.8 (±0.6) | Train time: 0.77 (±0.02)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 64; lambda:0.10) ===
# .....
# Acc (Train): 98.2 (±0.4) | Acc (Test):  91.5 (±0.4) | Train time: 0.76 (±0.02)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 64; lambda:1.00) ===
# .....
# Acc (Train): 97.2 (±0.3) | Acc (Test):  91.9 (±0.7) | Train time: 0.76 (±0.03)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 64; lambda:3.00) ===
# .....
# Acc (Train): 95.9 (±0.3) | Acc (Test):  92.2 (±0.4) | Train time: 0.75 (±0.02)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 64; lambda:5.00) ===
# .....
# Acc (Train): 95.0 (±0.1) | Acc (Test):  91.9 (±0.3) | Train time: 0.76 (±0.02)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 128; lambda:0.00) ===
# .....
# Acc (Train): 99.8 (±0.1) | Acc (Test):  89.5 (±0.5) | Train time: 1.51 (±0.09)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 128; lambda:0.01) ===
# .....
# Acc (Train): 99.5 (±0.2) | Acc (Test):  90.1 (±0.4) | Train time: 1.49 (±0.01)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 128; lambda:0.10) ===
# .....
# Acc (Train): 99.5 (±0.1) | Acc (Test):  91.1 (±0.5) | Train time: 1.50 (±0.03)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 128; lambda:1.00) ===
# .....
# Acc (Train): 98.8 (±0.2) | Acc (Test):  92.1 (±0.4) | Train time: 1.51 (±0.04)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 128; lambda:3.00) ===
# .....
# Acc (Train): 96.8 (±0.1) | Acc (Test):  92.4 (±0.5) | Train time: 1.51 (±0.02)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 128; lambda:5.00) ===
# .....
# Acc (Train): 95.3 (±0.3) | Acc (Test):  92.1 (±0.3) | Train time: 1.52 (±0.05)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 256; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  88.4 (±0.8) | Train time: 14.77 (±2.40)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 256; lambda:0.01) ===
# .....
# Acc (Train): 99.9 (±0.1) | Acc (Test):  89.2 (±0.9) | Train time: 2.96 (±0.05)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 256; lambda:0.10) ===
# .....
# Acc (Train): 99.9 (±0.1) | Acc (Test):  91.6 (±0.7) | Train time: 2.98 (±0.03)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 256; lambda:1.00) ===
# .....
# Acc (Train): 99.2 (±0.0) | Acc (Test):  92.8 (±0.3) | Train time: 2.98 (±0.04)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 256; lambda:3.00) ===
# .....
# Acc (Train): 96.9 (±0.1) | Acc (Test):  92.9 (±0.2) | Train time: 2.97 (±0.04)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 256; lambda:5.00) ===
# .....
# Acc (Train): 95.6 (±0.2) | Acc (Test):  92.2 (±0.4) | Train time: 2.99 (±0.03)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 512; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  87.5 (±0.8) | Train time: 34.07 (±6.32)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 512; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  91.1 (±1.1) | Train time: 5.48 (±0.04)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 512; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  91.3 (±0.4) | Train time: 5.50 (±0.07)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 512; lambda:1.00) ===
# .....
# Acc (Train): 99.2 (±0.1) | Acc (Test):  92.8 (±0.4) | Train time: 5.53 (±0.05)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 512; lambda:3.00) ===
# .....
# Acc (Train): 97.1 (±0.1) | Acc (Test):  92.8 (±0.5) | Train time: 5.53 (±0.02)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 512; lambda:5.00) ===
# .....
# Acc (Train): 95.6 (±0.2) | Acc (Test):  92.3 (±0.2) | Train time: 5.51 (±0.03)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 1024; lambda:0.00) ===
# .....
# Acc (Train): 99.9 (±0.1) | Acc (Test):  87.4 (±1.1) | Train time: 61.99 (±19.98)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 1024; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  91.5 (±0.4) | Train time: 10.91 (±0.75)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 1024; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  92.2 (±0.6) | Train time: 11.06 (±0.05)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 1024; lambda:1.00) ===
# .....
# Acc (Train): 99.3 (±0.1) | Acc (Test):  93.0 (±0.3) | Train time: 11.36 (±0.43)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 1024; lambda:3.00) ===
# .....
# Acc (Train): 97.0 (±0.1) | Acc (Test):  93.1 (±0.3) | Train time: 8.99 (±1.47)
# === Training network (hidden layer: 16, method: L-BFGS-B; num_iter: 1024; lambda:5.00) ===
# .....
# Acc (Train): 95.7 (±0.1) | Acc (Test):  92.5 (±0.2) | Train time: 9.47 (±2.19)
# === Training network (hidden layer: 25, method: TNC; num_iter: 64; lambda:0.00) ===
# .....
# Acc (Train): 91.8 (±1.5) | Acc (Test):  90.0 (±1.1) | Train time: 0.84 (±0.02)
# === Training network (hidden layer: 25, method: TNC; num_iter: 64; lambda:0.01) ===
# .....
# Acc (Train): 90.9 (±2.6) | Acc (Test):  88.7 (±1.9) | Train time: 0.83 (±0.02)
# === Training network (hidden layer: 25, method: TNC; num_iter: 64; lambda:0.10) ===
# .....
# Acc (Train): 92.5 (±0.5) | Acc (Test):  90.1 (±0.8) | Train time: 0.89 (±0.05)
# === Training network (hidden layer: 25, method: TNC; num_iter: 64; lambda:1.00) ===
# .....
# Acc (Train): 92.3 (±1.5) | Acc (Test):  90.3 (±1.3) | Train time: 0.84 (±0.02)
# === Training network (hidden layer: 25, method: TNC; num_iter: 64; lambda:3.00) ===
# .....
# Acc (Train): 91.9 (±1.0) | Acc (Test):  90.0 (±0.9) | Train time: 0.89 (±0.03)
# === Training network (hidden layer: 25, method: TNC; num_iter: 64; lambda:5.00) ===
# .....
# Acc (Train): 90.7 (±0.7) | Acc (Test):  89.1 (±0.9) | Train time: 0.87 (±0.03)
# === Training network (hidden layer: 25, method: TNC; num_iter: 128; lambda:0.00) ===
# .....
# Acc (Train): 98.4 (±0.2) | Acc (Test):  92.4 (±0.3) | Train time: 1.67 (±0.05)
# === Training network (hidden layer: 25, method: TNC; num_iter: 128; lambda:0.01) ===
# .....
# Acc (Train): 98.5 (±0.4) | Acc (Test):  92.3 (±0.4) | Train time: 1.87 (±0.13)
# === Training network (hidden layer: 25, method: TNC; num_iter: 128; lambda:0.10) ===
# .....
# Acc (Train): 98.5 (±0.5) | Acc (Test):  92.8 (±0.2) | Train time: 2.01 (±0.13)
# === Training network (hidden layer: 25, method: TNC; num_iter: 128; lambda:1.00) ===
# .....
# Acc (Train): 97.4 (±0.8) | Acc (Test):  92.6 (±0.5) | Train time: 2.02 (±0.12)
# === Training network (hidden layer: 25, method: TNC; num_iter: 128; lambda:3.00) ===
# .....
# Acc (Train): 95.7 (±1.2) | Acc (Test):  92.4 (±0.7) | Train time: 1.98 (±0.07)
# === Training network (hidden layer: 25, method: TNC; num_iter: 128; lambda:5.00) ===
# .....
# Acc (Train): 95.3 (±0.2) | Acc (Test):  92.3 (±0.2) | Train time: 1.93 (±0.06)
# === Training network (hidden layer: 25, method: TNC; num_iter: 256; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  92.0 (±0.7) | Train time: 3.65 (±0.07)
# === Training network (hidden layer: 25, method: TNC; num_iter: 256; lambda:0.01) ===
# .....
# Acc (Train): 99.8 (±0.3) | Acc (Test):  91.8 (±1.0) | Train time: 3.91 (±0.22)
# === Training network (hidden layer: 25, method: TNC; num_iter: 256; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  92.9 (±0.3) | Train time: 3.47 (±0.19)
# === Training network (hidden layer: 25, method: TNC; num_iter: 256; lambda:1.00) ===
# .....
# Acc (Train): 99.4 (±0.1) | Acc (Test):  93.6 (±0.2) | Train time: 3.27 (±0.07)
# === Training network (hidden layer: 25, method: TNC; num_iter: 256; lambda:3.00) ===
# .....
# Acc (Train): 97.4 (±0.2) | Acc (Test):  93.3 (±0.3) | Train time: 3.25 (±0.07)
# === Training network (hidden layer: 25, method: TNC; num_iter: 256; lambda:5.00) ===
# .....
# Acc (Train): 95.9 (±0.1) | Acc (Test):  92.6 (±0.1) | Train time: 3.23 (±0.02)
# === Training network (hidden layer: 25, method: TNC; num_iter: 512; lambda:0.00) ===
# .....
# Acc (Train): 99.9 (±0.1) | Acc (Test):  91.9 (±0.7) | Train time: 4.77 (±0.57)
# === Training network (hidden layer: 25, method: TNC; num_iter: 512; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  92.1 (±0.5) | Train time: 5.36 (±0.74)
# === Training network (hidden layer: 25, method: TNC; num_iter: 512; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  92.9 (±0.2) | Train time: 6.21 (±0.65)
# === Training network (hidden layer: 25, method: TNC; num_iter: 512; lambda:1.00) ===
# .....
# Acc (Train): 98.9 (±1.0) | Acc (Test):  93.4 (±0.8) | Train time: 5.57 (±1.50)
# === Training network (hidden layer: 25, method: TNC; num_iter: 512; lambda:3.00) ===
# .....
# Acc (Train): 97.6 (±0.1) | Acc (Test):  93.6 (±0.3) | Train time: 7.15 (±0.07)
# === Training network (hidden layer: 25, method: TNC; num_iter: 512; lambda:5.00) ===
# .....
# Acc (Train): 96.1 (±0.1) | Acc (Test):  93.0 (±0.2) | Train time: 7.25 (±0.22)
# === Training network (hidden layer: 25, method: TNC; num_iter: 1024; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  91.8 (±0.5) | Train time: 5.54 (±0.70)
# === Training network (hidden layer: 25, method: TNC; num_iter: 1024; lambda:0.01) ===
# .....
# Acc (Train): 99.9 (±0.1) | Acc (Test):  92.3 (±0.3) | Train time: 4.91 (±0.84)
# === Training network (hidden layer: 25, method: TNC; num_iter: 1024; lambda:0.10) ===
# .....
# Acc (Train): 99.9 (±0.1) | Acc (Test):  93.0 (±0.6) | Train time: 6.17 (±0.58)
# === Training network (hidden layer: 25, method: TNC; num_iter: 1024; lambda:1.00) ===
# .....
# Acc (Train): 98.8 (±1.1) | Acc (Test):  93.4 (±0.9) | Train time: 10.34 (±5.26)
# === Training network (hidden layer: 25, method: TNC; num_iter: 1024; lambda:3.00) ===
# .....
# Acc (Train): 97.6 (±0.1) | Acc (Test):  93.6 (±0.2) | Train time: 15.03 (±0.71)
# === Training network (hidden layer: 25, method: TNC; num_iter: 1024; lambda:5.00) ===
# .....
# Acc (Train): 96.2 (±0.1) | Acc (Test):  93.1 (±0.2) | Train time: 14.19 (±0.99)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 64; lambda:0.00) ===
# .....
# Acc (Train): 99.4 (±0.1) | Acc (Test):  91.4 (±0.6) | Train time: 1.15 (±0.07)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 64; lambda:0.01) ===
# .....
# Acc (Train): 99.5 (±0.2) | Acc (Test):  91.7 (±0.5) | Train time: 1.03 (±0.04)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 64; lambda:0.10) ===
# .....
# Acc (Train): 99.3 (±0.1) | Acc (Test):  92.6 (±0.2) | Train time: 1.15 (±0.01)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 64; lambda:1.00) ===
# .....
# Acc (Train): 98.6 (±0.1) | Acc (Test):  93.3 (±0.4) | Train time: 1.18 (±0.02)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 64; lambda:3.00) ===
# .....
# Acc (Train): 96.5 (±0.2) | Acc (Test):  92.8 (±0.4) | Train time: 1.10 (±0.05)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 64; lambda:5.00) ===
# .....
# Acc (Train): 95.4 (±0.0) | Acc (Test):  92.0 (±0.3) | Train time: 1.08 (±0.07)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 128; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  90.7 (±0.5) | Train time: 7.38 (±2.61)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 128; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  91.8 (±0.5) | Train time: 2.06 (±0.10)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 128; lambda:0.10) ===
# .....
# Acc (Train): 99.9 (±0.1) | Acc (Test):  92.6 (±0.5) | Train time: 2.12 (±0.09)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 128; lambda:1.00) ===
# .....
# Acc (Train): 99.4 (±0.0) | Acc (Test):  93.6 (±0.2) | Train time: 2.04 (±0.04)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 128; lambda:3.00) ===
# .....
# Acc (Train): 97.3 (±0.2) | Acc (Test):  93.2 (±0.2) | Train time: 1.99 (±0.08)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 128; lambda:5.00) ===
# .....
# Acc (Train): 95.9 (±0.0) | Acc (Test):  92.6 (±0.4) | Train time: 1.89 (±0.12)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 256; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  90.6 (±0.8) | Train time: 10.73 (±3.24)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 256; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  92.6 (±0.4) | Train time: 3.98 (±0.10)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 256; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  93.3 (±0.3) | Train time: 3.92 (±0.19)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 256; lambda:1.00) ===
# .....
# Acc (Train): 99.6 (±0.0) | Acc (Test):  93.7 (±0.4) | Train time: 3.87 (±0.10)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 256; lambda:3.00) ===
# .....
# Acc (Train): 97.7 (±0.1) | Acc (Test):  93.6 (±0.2) | Train time: 3.86 (±0.14)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 256; lambda:5.00) ===
# .....
# Acc (Train): 96.1 (±0.1) | Acc (Test):  92.9 (±0.1) | Train time: 4.20 (±0.20)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 512; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  90.3 (±0.8) | Train time: 11.82 (±2.78)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 512; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  92.5 (±0.1) | Train time: 10.98 (±4.15)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 512; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  93.4 (±0.3) | Train time: 8.65 (±0.09)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 512; lambda:1.00) ===
# .....
# Acc (Train): 99.7 (±0.1) | Acc (Test):  94.0 (±0.2) | Train time: 8.24 (±0.21)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 512; lambda:3.00) ===
# .....
# Acc (Train): 97.8 (±0.1) | Acc (Test):  93.6 (±0.2) | Train time: 8.73 (±0.31)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 512; lambda:5.00) ===
# .....
# Acc (Train): 96.1 (±0.1) | Acc (Test):  93.1 (±0.2) | Train time: 8.24 (±0.11)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 1024; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  91.3 (±0.7) | Train time: 8.98 (±2.12)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 1024; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  92.8 (±0.5) | Train time: 7.72 (±2.23)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 1024; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  93.8 (±0.1) | Train time: 15.48 (±0.78)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 1024; lambda:1.00) ===
# .....
# Acc (Train): 99.7 (±0.0) | Acc (Test):  94.2 (±0.2) | Train time: 16.89 (±0.24)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 1024; lambda:3.00) ===
# .....
# Acc (Train): 97.8 (±0.1) | Acc (Test):  93.7 (±0.1) | Train time: 14.97 (±2.57)
# === Training network (hidden layer: 25, method: L-BFGS-B; num_iter: 1024; lambda:5.00) ===
# .....
# Acc (Train): 96.2 (±0.0) | Acc (Test):  93.0 (±0.2) | Train time: 13.26 (±2.63)
# === Training network (hidden layer: 64, method: TNC; num_iter: 64; lambda:0.00) ===
# .....
# Acc (Train): 92.5 (±0.9) | Acc (Test):  90.2 (±0.5) | Train time: 1.52 (±0.06)
# === Training network (hidden layer: 64, method: TNC; num_iter: 64; lambda:0.01) ===
# .....
# Acc (Train): 94.8 (±0.9) | Acc (Test):  91.7 (±0.6) | Train time: 1.45 (±0.07)
# === Training network (hidden layer: 64, method: TNC; num_iter: 64; lambda:0.10) ===
# .....
# Acc (Train): 94.2 (±1.5) | Acc (Test):  91.0 (±1.0) | Train time: 1.44 (±0.03)
# === Training network (hidden layer: 64, method: TNC; num_iter: 64; lambda:1.00) ===
# .....
# Acc (Train): 93.1 (±1.8) | Acc (Test):  90.7 (±1.0) | Train time: 1.48 (±0.04)
# === Training network (hidden layer: 64, method: TNC; num_iter: 64; lambda:3.00) ===
# .....
# Acc (Train): 92.4 (±1.4) | Acc (Test):  90.5 (±1.1) | Train time: 1.48 (±0.02)
# === Training network (hidden layer: 64, method: TNC; num_iter: 64; lambda:5.00) ===
# .....
# Acc (Train): 92.0 (±0.8) | Acc (Test):  90.0 (±0.5) | Train time: 1.45 (±0.04)
# === Training network (hidden layer: 64, method: TNC; num_iter: 128; lambda:0.00) ===
# .....
# Acc (Train): 99.6 (±0.4) | Acc (Test):  93.7 (±0.2) | Train time: 2.90 (±0.17)
# === Training network (hidden layer: 64, method: TNC; num_iter: 128; lambda:0.01) ===
# .....
# Acc (Train): 99.1 (±1.3) | Acc (Test):  93.3 (±0.5) | Train time: 2.83 (±0.07)
# === Training network (hidden layer: 64, method: TNC; num_iter: 128; lambda:0.10) ===
# .....
# Acc (Train): 99.6 (±0.3) | Acc (Test):  93.5 (±0.3) | Train time: 3.03 (±0.26)
# === Training network (hidden layer: 64, method: TNC; num_iter: 128; lambda:1.00) ===
# .....
# Acc (Train): 98.9 (±0.4) | Acc (Test):  93.7 (±0.2) | Train time: 2.82 (±0.03)
# === Training network (hidden layer: 64, method: TNC; num_iter: 128; lambda:3.00) ===
# .....
# Acc (Train): 96.9 (±0.3) | Acc (Test):  92.8 (±0.2) | Train time: 2.82 (±0.03)
# === Training network (hidden layer: 64, method: TNC; num_iter: 128; lambda:5.00) ===
# .....
# Acc (Train): 95.7 (±0.2) | Acc (Test):  92.4 (±0.4) | Train time: 2.96 (±0.22)
# === Training network (hidden layer: 64, method: TNC; num_iter: 256; lambda:0.00) ===
# .....
# Acc (Train): 99.9 (±0.2) | Acc (Test):  93.6 (±0.4) | Train time: 6.51 (±0.79)
# === Training network (hidden layer: 64, method: TNC; num_iter: 256; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.0 (±0.3) | Train time: 5.88 (±0.27)
# === Training network (hidden layer: 64, method: TNC; num_iter: 256; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.5 (±0.3) | Train time: 6.18 (±0.22)
# === Training network (hidden layer: 64, method: TNC; num_iter: 256; lambda:1.00) ===
# .....
# Acc (Train): 99.7 (±0.2) | Acc (Test):  94.2 (±0.5) | Train time: 6.37 (±0.52)
# === Training network (hidden layer: 64, method: TNC; num_iter: 256; lambda:3.00) ===
# .....
# Acc (Train): 98.0 (±0.1) | Acc (Test):  94.0 (±0.2) | Train time: 6.10 (±0.14)
# === Training network (hidden layer: 64, method: TNC; num_iter: 256; lambda:5.00) ===
# .....
# Acc (Train): 96.0 (±0.6) | Acc (Test):  93.0 (±0.5) | Train time: 6.03 (±0.15)
# === Training network (hidden layer: 64, method: TNC; num_iter: 512; lambda:0.00) ===
# .....
# Acc (Train): 99.8 (±0.5) | Acc (Test):  93.7 (±0.3) | Train time: 7.06 (±0.86)
# === Training network (hidden layer: 64, method: TNC; num_iter: 512; lambda:0.01) ===
# .....
# Acc (Train): 99.2 (±1.2) | Acc (Test):  93.8 (±0.6) | Train time: 7.53 (±2.15)
# === Training network (hidden layer: 64, method: TNC; num_iter: 512; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.5 (±0.2) | Train time: 9.44 (±1.84)
# === Training network (hidden layer: 64, method: TNC; num_iter: 512; lambda:1.00) ===
# .....
# Acc (Train): 99.7 (±0.3) | Acc (Test):  94.6 (±0.3) | Train time: 9.83 (±2.41)
# === Training network (hidden layer: 64, method: TNC; num_iter: 512; lambda:3.00) ===
# .....
# Acc (Train): 98.2 (±0.1) | Acc (Test):  94.1 (±0.2) | Train time: 11.77 (±0.18)
# === Training network (hidden layer: 64, method: TNC; num_iter: 512; lambda:5.00) ===
# .....
# Acc (Train): 96.7 (±0.0) | Acc (Test):  93.5 (±0.1) | Train time: 11.66 (±0.08)
# === Training network (hidden layer: 64, method: TNC; num_iter: 1024; lambda:0.00) ===
# .....
# Acc (Train): 99.0 (±1.9) | Acc (Test):  93.7 (±0.8) | Train time: 6.50 (±1.10)
# === Training network (hidden layer: 64, method: TNC; num_iter: 1024; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.3 (±0.7) | Train time: 12.24 (±2.13)
# === Training network (hidden layer: 64, method: TNC; num_iter: 1024; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.4 (±0.2) | Train time: 9.89 (±2.20)
# === Training network (hidden layer: 64, method: TNC; num_iter: 1024; lambda:1.00) ===
# .....
# Acc (Train): 99.8 (±0.1) | Acc (Test):  94.5 (±0.6) | Train time: 14.49 (±7.89)
# === Training network (hidden layer: 64, method: TNC; num_iter: 1024; lambda:3.00) ===
# .....
# Acc (Train): 98.1 (±0.3) | Acc (Test):  94.0 (±0.3) | Train time: 18.80 (±6.41)
# === Training network (hidden layer: 64, method: TNC; num_iter: 1024; lambda:5.00) ===
# .....
# Acc (Train): 95.3 (±2.2) | Acc (Test):  92.5 (±1.4) | Train time: 14.85 (±8.36)
# === Training network (hidden layer: 64, method: L-BFGS-B; num_iter: 64; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  93.6 (±0.5) | Train time: 2.49 (±1.26)
# === Training network (hidden layer: 64, method: L-BFGS-B; num_iter: 64; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  93.5 (±0.6) | Train time: 1.57 (±0.15)
# === Training network (hidden layer: 64, method: L-BFGS-B; num_iter: 64; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.2 (±0.3) | Train time: 1.50 (±0.02)
# === Training network (hidden layer: 64, method: L-BFGS-B; num_iter: 64; lambda:1.00) ===
# .....
# Acc (Train): 99.1 (±0.2) | Acc (Test):  94.1 (±0.4) | Train time: 1.53 (±0.03)
# === Training network (hidden layer: 64, method: L-BFGS-B; num_iter: 64; lambda:3.00) ===
# .....
# Acc (Train): 97.1 (±0.2) | Acc (Test):  93.2 (±0.4) | Train time: 1.54 (±0.02)
# === Training network (hidden layer: 64, method: L-BFGS-B; num_iter: 64; lambda:5.00) ===
# .....
# Acc (Train): 95.5 (±0.2) | Acc (Test):  92.4 (±0.4) | Train time: 1.52 (±0.03)
# === Training network (hidden layer: 64, method: L-BFGS-B; num_iter: 128; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  93.8 (±0.4) | Train time: 3.97 (±0.51)
# === Training network (hidden layer: 64, method: L-BFGS-B; num_iter: 128; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.5 (±0.5) | Train time: 3.04 (±0.09)
# === Training network (hidden layer: 64, method: L-BFGS-B; num_iter: 128; lambda:0.10) ===
# .....
# ...
# === Training network (hidden layer: 128, method: TNC; num_iter: 1024; lambda:5.00) ===
# .....
# Acc (Train): 96.8 (±0.0) | Acc (Test):  93.5 (±0.1) | Train time: 47.32 (±1.11)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 64; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.0 (±0.5) | Train time: 6.64 (±1.01)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 64; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.5 (±0.4) | Train time: 3.65 (±0.46)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 64; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.6 (±0.3) | Train time: 3.25 (±0.08)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 64; lambda:1.00) ===
# .....
# Acc (Train): 98.9 (±0.1) | Acc (Test):  94.0 (±0.4) | Train time: 3.33 (±0.08)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 64; lambda:3.00) ===
# .....
# Acc (Train): 96.5 (±0.2) | Acc (Test):  92.7 (±0.2) | Train time: 3.28 (±0.09)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 64; lambda:5.00) ===
# .....
# Acc (Train): 95.3 (±0.1) | Acc (Test):  92.2 (±0.3) | Train time: 3.40 (±0.14)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 128; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  93.9 (±0.4) | Train time: 8.16 (±1.90)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 128; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.8 (±0.2) | Train time: 6.70 (±0.39)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 128; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  95.0 (±0.3) | Train time: 6.31 (±0.23)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 128; lambda:1.00) ===
# .....
# Acc (Train): 99.9 (±0.0) | Acc (Test):  94.9 (±0.4) | Train time: 6.13 (±0.05)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 128; lambda:3.00) ===
# .....
# Acc (Train): 97.9 (±0.0) | Acc (Test):  93.8 (±0.1) | Train time: 6.19 (±0.14)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 128; lambda:5.00) ===
# .....
# Acc (Train): 96.4 (±0.1) | Acc (Test):  93.4 (±0.2) | Train time: 6.42 (±0.13)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 256; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.4 (±0.4) | Train time: 8.99 (±1.53)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 256; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  95.5 (±0.2) | Train time: 10.76 (±1.98)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 256; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  95.5 (±0.2) | Train time: 13.05 (±0.45)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 256; lambda:1.00) ===
# .....
# Acc (Train): 99.9 (±0.0) | Acc (Test):  95.2 (±0.3) | Train time: 13.00 (±0.38)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 256; lambda:3.00) ===
# .....
# Acc (Train): 98.2 (±0.0) | Acc (Test):  94.0 (±0.2) | Train time: 13.79 (±0.71)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 256; lambda:5.00) ===
# .....
# Acc (Train): 96.6 (±0.1) | Acc (Test):  93.4 (±0.1) | Train time: 12.40 (±0.25)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 512; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  93.8 (±0.5) | Train time: 7.87 (±0.58)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 512; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  95.3 (±0.2) | Train time: 8.44 (±0.49)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 512; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  95.9 (±0.2) | Train time: 25.91 (±2.30)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 512; lambda:1.00) ===
# .....
# Acc (Train): 99.9 (±0.0) | Acc (Test):  95.2 (±0.2) | Train time: 25.13 (±0.73)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 512; lambda:3.00) ===
# .....
# Acc (Train): 98.3 (±0.0) | Acc (Test):  94.1 (±0.1) | Train time: 26.95 (±0.99)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 512; lambda:5.00) ===
# .....
# Acc (Train): 96.7 (±0.1) | Acc (Test):  93.5 (±0.1) | Train time: 28.55 (±1.15)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 1024; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.1 (±0.1) | Train time: 8.67 (±0.90)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 1024; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  95.3 (±0.1) | Train time: 9.59 (±2.09)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 1024; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  95.8 (±0.2) | Train time: 28.62 (±2.69)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 1024; lambda:1.00) ===
# .....
# Acc (Train): 99.9 (±0.0) | Acc (Test):  95.4 (±0.2) | Train time: 49.93 (±1.82)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 1024; lambda:3.00) ===
# .....
# Acc (Train): 98.3 (±0.0) | Acc (Test):  94.1 (±0.1) | Train time: 51.60 (±1.93)
# === Training network (hidden layer: 128, method: L-BFGS-B; num_iter: 1024; lambda:5.00) ===
# .....
# Acc (Train): 96.7 (±0.0) | Acc (Test):  93.5 (±0.1) | Train time: 52.99 (±1.87)
# === Training network (hidden layer: 512, method: TNC; num_iter: 64; lambda:0.00) ===
# .....
# Acc (Train): 92.3 (±0.8) | Acc (Test):  89.7 (±0.5) | Train time: 9.11 (±0.09)
# === Training network (hidden layer: 512, method: TNC; num_iter: 64; lambda:0.01) ===
# .....
# Acc (Train): 92.6 (±0.4) | Acc (Test):  90.0 (±0.4) | Train time: 9.12 (±0.15)
# === Training network (hidden layer: 512, method: TNC; num_iter: 64; lambda:0.10) ===
# .....
# Acc (Train): 92.0 (±0.8) | Acc (Test):  89.3 (±0.3) | Train time: 9.23 (±0.17)
# === Training network (hidden layer: 512, method: TNC; num_iter: 64; lambda:1.00) ===
# .....
# Acc (Train): 91.7 (±1.3) | Acc (Test):  89.2 (±0.7) | Train time: 9.25 (±0.23)
# === Training network (hidden layer: 512, method: TNC; num_iter: 64; lambda:3.00) ===
# .....
# Acc (Train): 91.3 (±1.0) | Acc (Test):  89.2 (±0.4) | Train time: 9.08 (±0.10)
# === Training network (hidden layer: 512, method: TNC; num_iter: 64; lambda:5.00) ===
# .....
# Acc (Train): 90.8 (±0.8) | Acc (Test):  88.7 (±0.4) | Train time: 9.04 (±0.10)
# === Training network (hidden layer: 512, method: TNC; num_iter: 128; lambda:0.00) ===
# .....
# Acc (Train): 98.6 (±0.9) | Acc (Test):  93.7 (±0.8) | Train time: 17.97 (±0.50)
# === Training network (hidden layer: 512, method: TNC; num_iter: 128; lambda:0.01) ===
# .....
# Acc (Train): 93.4 (±3.4) | Acc (Test):  90.3 (±2.1) | Train time: 20.60 (±1.94)
# === Training network (hidden layer: 512, method: TNC; num_iter: 128; lambda:0.10) ===
# .....
# Acc (Train): 97.6 (±2.0) | Acc (Test):  92.8 (±1.5) | Train time: 18.45 (±1.30)
# === Training network (hidden layer: 512, method: TNC; num_iter: 128; lambda:1.00) ===
# .....
# Acc (Train): 97.8 (±0.1) | Acc (Test):  93.3 (±0.1) | Train time: 18.09 (±0.34)
# === Training network (hidden layer: 512, method: TNC; num_iter: 128; lambda:3.00) ===
# .....
# Acc (Train): 79.0 (±33.1) | Acc (Test):  76.1 (±31.6) | Train time: 20.09 (±0.52)
# === Training network (hidden layer: 512, method: TNC; num_iter: 128; lambda:5.00) ===
# .....
# Acc (Train): 94.4 (±0.2) | Acc (Test):  91.0 (±0.2) | Train time: 20.08 (±0.70)
# === Training network (hidden layer: 512, method: TNC; num_iter: 256; lambda:0.00) ===
# .....
# Acc (Train): 97.8 (±1.5) | Acc (Test):  93.1 (±0.7) | Train time: 33.67 (±4.20)
# === Training network (hidden layer: 512, method: TNC; num_iter: 256; lambda:0.01) ===
# .....
# Acc (Train): 97.4 (±1.4) | Acc (Test):  93.0 (±0.9) | Train time: 35.25 (±4.27)
# === Training network (hidden layer: 512, method: TNC; num_iter: 256; lambda:0.10) ===
# .....
# Acc (Train): 91.8 (±16.5) | Acc (Test):  87.8 (±14.1) | Train time: 37.62 (±8.15)
# === Training network (hidden layer: 512, method: TNC; num_iter: 256; lambda:1.00) ===
# .....
# Acc (Train): 99.8 (±0.1) | Acc (Test):  94.8 (±0.2) | Train time: 38.22 (±2.31)
# === Training network (hidden layer: 512, method: TNC; num_iter: 256; lambda:3.00) ===
# .....
# Acc (Train): 96.9 (±1.6) | Acc (Test):  92.9 (±1.3) | Train time: 38.47 (±2.18)
# === Training network (hidden layer: 512, method: TNC; num_iter: 256; lambda:5.00) ===
# .....
# Acc (Train): 96.0 (±0.1) | Acc (Test):  93.2 (±0.2) | Train time: 38.42 (±0.24)
# === Training network (hidden layer: 512, method: TNC; num_iter: 512; lambda:0.00) ===
# .....
# Acc (Train): 97.2 (±1.5) | Acc (Test):  92.9 (±0.6) | Train time: 39.16 (±2.03)
# === Training network (hidden layer: 512, method: TNC; num_iter: 512; lambda:0.01) ===
# .....
# Acc (Train): 98.1 (±1.1) | Acc (Test):  93.4 (±1.3) | Train time: 48.40 (±18.18)
# === Training network (hidden layer: 512, method: TNC; num_iter: 512; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  95.7 (±0.3) | Train time: 66.44 (±1.81)
# === Training network (hidden layer: 512, method: TNC; num_iter: 512; lambda:1.00) ===
# .....
# Acc (Train): 92.7 (±14.5) | Acc (Test):  88.6 (±13.4) | Train time: 60.59 (±21.43)
# === Training network (hidden layer: 512, method: TNC; num_iter: 512; lambda:3.00) ===
# .....
# Acc (Train): 98.2 (±0.1) | Acc (Test):  94.0 (±0.2) | Train time: 71.61 (±1.93)
# === Training network (hidden layer: 512, method: TNC; num_iter: 512; lambda:5.00) ===
# .....
# Acc (Train): 96.6 (±0.1) | Acc (Test):  93.5 (±0.1) | Train time: 72.70 (±2.18)
# === Training network (hidden layer: 512, method: TNC; num_iter: 1024; lambda:0.00) ===
# .....
# Acc (Train): 97.0 (±1.7) | Acc (Test):  92.4 (±0.7) | Train time: 32.08 (±2.33)
# === Training network (hidden layer: 512, method: TNC; num_iter: 1024; lambda:0.01) ===
# .....
# Acc (Train): 71.9 (±33.3) | Acc (Test):  69.7 (±31.6) | Train time: 28.01 (±10.82)
# === Training network (hidden layer: 512, method: TNC; num_iter: 1024; lambda:0.10) ===
# .....
# Acc (Train): 82.6 (±34.8) | Acc (Test):  79.1 (±33.3) | Train time: 100.16 (±53.76)
# === Training network (hidden layer: 512, method: TNC; num_iter: 1024; lambda:1.00) ===
# .....
# Acc (Train): 82.2 (±35.5) | Acc (Test):  78.5 (±33.5) | Train time: 115.65 (±49.49)
# === Training network (hidden layer: 512, method: TNC; num_iter: 1024; lambda:3.00) ===
# .....
# Acc (Train): 98.2 (±0.0) | Acc (Test):  94.0 (±0.1) | Train time: 125.41 (±0.48)
# === Training network (hidden layer: 512, method: TNC; num_iter: 1024; lambda:5.00) ===
# .....
# Acc (Train): 96.8 (±0.1) | Acc (Test):  93.5 (±0.1) | Train time: 125.19 (±0.31)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 64; lambda:0.00) ===
# .....
# Acc (Train): 98.5 (±0.2) | Acc (Test):  93.4 (±0.4) | Train time: 9.28 (±0.92)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 64; lambda:0.01) ===
# .....
# Acc (Train): 98.2 (±0.8) | Acc (Test):  93.7 (±0.5) | Train time: 8.83 (±0.19)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 64; lambda:0.10) ===
# .....
# Acc (Train): 97.8 (±0.5) | Acc (Test):  93.6 (±0.6) | Train time: 8.92 (±0.20)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 64; lambda:1.00) ===
# .....
# Acc (Train): 95.0 (±0.1) | Acc (Test):  91.6 (±0.3) | Train time: 8.83 (±0.16)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 64; lambda:3.00) ===
# .....
# Acc (Train): 93.4 (±0.2) | Acc (Test):  90.5 (±0.4) | Train time: 8.88 (±0.07)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 64; lambda:5.00) ===
# .....
# Acc (Train): 92.9 (±0.2) | Acc (Test):  90.1 (±0.2) | Train time: 8.80 (±0.15)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 128; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.8 (±0.3) | Train time: 33.29 (±1.94)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 128; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.9 (±0.2) | Train time: 70.24 (±7.34)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 128; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.9 (±0.2) | Train time: 17.04 (±0.18)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 128; lambda:1.00) ===
# .....
# Acc (Train): 99.3 (±0.1) | Acc (Test):  94.2 (±0.3) | Train time: 17.40 (±0.24)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 128; lambda:3.00) ===
# .....
# Acc (Train): 96.5 (±0.1) | Acc (Test):  92.9 (±0.2) | Train time: 17.34 (±0.20)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 128; lambda:5.00) ===
# .....
# Acc (Train): 94.7 (±0.2) | Acc (Test):  91.3 (±0.3) | Train time: 17.51 (±0.27)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 256; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.7 (±0.3) | Train time: 31.70 (±2.50)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 256; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  95.3 (±0.1) | Train time: 108.18 (±15.78)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 256; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  95.4 (±0.1) | Train time: 33.72 (±0.23)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 256; lambda:1.00) ===
# .....
# Acc (Train): 99.8 (±0.0) | Acc (Test):  94.8 (±0.2) | Train time: 33.94 (±0.18)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 256; lambda:3.00) ===
# .....
# Acc (Train): 97.9 (±0.1) | Acc (Test):  93.9 (±0.1) | Train time: 34.30 (±0.29)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 256; lambda:5.00) ===
# .....
# Acc (Train): 96.1 (±0.1) | Acc (Test):  93.1 (±0.1) | Train time: 34.45 (±0.41)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 512; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.9 (±0.3) | Train time: 36.93 (±4.62)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 512; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  95.6 (±0.2) | Train time: 89.99 (±15.32)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 512; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  95.7 (±0.1) | Train time: 67.35 (±0.49)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 512; lambda:1.00) ===
# .....
# Acc (Train): 99.9 (±0.0) | Acc (Test):  95.3 (±0.2) | Train time: 68.45 (±0.28)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 512; lambda:3.00) ===
# .....
# Acc (Train): 98.2 (±0.0) | Acc (Test):  94.0 (±0.2) | Train time: 68.43 (±0.17)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 512; lambda:5.00) ===
# .....
# Acc (Train): 96.6 (±0.1) | Acc (Test):  93.5 (±0.1) | Train time: 68.80 (±0.78)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 1024; lambda:0.00) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  94.7 (±0.4) | Train time: 33.77 (±3.31)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 1024; lambda:0.01) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  95.5 (±0.3) | Train time: 85.10 (±10.63)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 1024; lambda:0.10) ===
# .....
# Acc (Train): 100.0 (±0.0) | Acc (Test):  96.0 (±0.2) | Train time: 104.14 (±7.30)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 1024; lambda:1.00) ===
# .....
# Acc (Train): 99.9 (±0.0) | Acc (Test):  95.5 (±0.2) | Train time: 136.71 (±1.38)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 1024; lambda:3.00) ===
# .....
# Acc (Train): 98.2 (±0.1) | Acc (Test):  94.1 (±0.1) | Train time: 136.26 (±1.00)
# === Training network (hidden layer: 512, method: L-BFGS-B; num_iter: 1024; lambda:5.00) ===
# .....
# Acc (Train): 96.7 (±0.1) | Acc (Test):  93.6 (±0.1) | Train time: 136.98 (±1.00)

# %% [markdown]
# ## Results
#
# In the previous code, we tested several combinations for number of iterations, regularization term, and optimization method
# Considering we are using the train set to analyse the results, our goal, besides deducing the effect of each hyperparameter used, is to understand which combinations generates good results without overfitting.
#
# ### Effect of changing hyperparameters
#
# In this section, we broadly analyse the results, and our first one relates to the effect of each optimization method.
# Considering that there are several combinations for the three hyperparameters, we want to see the method's influence regardless the other hyperparameters.
# Thus, we take the average of the metrics for each distinct method based on the results save on `report/method_results.xlsx`

# %%
df = pd.read_excel("report/method_results.xlsx")

print("Checking methods influence")
for method in methods_list:
    acc = np.mean(df[df["Method"]==method]["Acc mean"])
    acc_std = np.std(df[df["Method"]==method]["Acc mean"])
    acc_test = np.mean(df[df["Method"]==method]["Acc test mean"])
    acc_std_test = np.std(df[df["Method"]==method]["Acc test mean"])

    print("Method\t%s\tTrain: %.1f%% (±%.1f), Test: %.1f%% (±%.1f)" % (method, acc, acc_std, acc_test, acc_std_test))
# Out:
# Checking methods influence
# Method	TNC	Train: 93.2% (±8.3), Test: 88.4% (±7.6)
# Method	L-BFGS-B	Train: 96.3% (±5.2), Test: 90.4% (±5.8)

# %%
print("Checking hidden layer size influence")
for hidden_layer_size in hidden_layer_list:
    acc = np.mean(df[df["Hidden Layer"]==hidden_layer_size]["Acc mean"])
    acc_std = np.std(df[df["Hidden Layer"]==hidden_layer_size]["Acc mean"])
    acc_test = np.mean(df[df["Hidden Layer"]==hidden_layer_size]["Acc test mean"])
    acc_std_test = np.std(df[df["Hidden Layer"]==hidden_layer_size]["Acc test mean"])

    print("Hidden Layer\t%d\tTrain: %.1f%% (±%.1f), Test: %.1f%% (±%.1f)" % (hidden_layer_size, acc, acc_std, acc_test, acc_std_test))
# Out:
# Checking hidden layer size influence
# Hidden Layer	4	Train: 82.8% (±8.6), Test: 76.6% (±7.0)
# Hidden Layer	8	Train: 94.5% (±4.7), Test: 87.8% (±3.3)
# Hidden Layer	16	Train: 97.3% (±2.9), Test: 91.2% (±1.6)
# Hidden Layer	25	Train: 97.9% (±2.6), Test: 92.4% (±1.2)
# Hidden Layer	64	Train: 98.3% (±2.2), Test: 93.6% (±1.2)
# Hidden Layer	128	Train: 96.9% (±5.9), Test: 92.6% (±5.0)
# Hidden Layer	512	Train: 95.9% (±5.4), Test: 91.9% (±4.9)

# %%
print("Checking lambda's influence")
for lambda_ in lambda_list:
    acc = np.mean(df[df["lambda_"]==lambda_]["Acc mean"])
    acc_std = np.std(df[df["lambda_"]==lambda_]["Acc mean"])
    acc_test = np.mean(df[df["lambda_"]==lambda_]["Acc test mean"])
    acc_std_test = np.std(df[df["lambda_"]==lambda_]["Acc test mean"])
    print("Lambda: %.2f\t Train: %.1f%% (±%.1f), Test: %.1f%% (±%.1f)" % (lambda_, acc, acc_std, acc_test, acc_std_test))
# Out:
# Checking lambda's influence
# Lambda: 0.00	 Train: 95.5% (±7.5), Test: 88.2% (±7.5)
# Lambda: 0.01	 Train: 95.4% (±7.8), Test: 88.7% (±7.6)
# Lambda: 0.10	 Train: 95.3% (±8.1), Test: 89.0% (±7.7)
# Lambda: 1.00	 Train: 95.6% (±6.5), Test: 90.6% (±6.0)
# Lambda: 3.00	 Train: 94.2% (±5.7), Test: 90.4% (±5.4)
# Lambda: 5.00	 Train: 92.8% (±6.5), Test: 89.8% (±6.1)

# %%
print("Checking num iterations's influence")
for num_iter in num_iters_list:

    acc = np.mean(df[df["Num_Inter"]==num_iter]["Acc mean"])
    acc_std = np.std(df[df["Num_Inter"]==num_iter]["Acc mean"])
    acc_test = np.mean(df[df["Num_Inter"]==num_iter]["Acc test mean"])
    acc_std_test = np.std(df[df["Num_Inter"]==num_iter]["Acc test mean"])
    
    print("Num Iterations: %d\tTrain: %.1f%% (±%.1f), Test: %.1f%% (±%.1f)" %  (num_iter, acc, acc_std, acc_test, acc_std_test))
# Out:
# Checking num iterations's influence
# Num Iterations: 64	Train: 89.5% (±10.5), Test: 86.2% (±9.5)
# Num Iterations: 128	Train: 94.9% (±6.1), Test: 89.8% (±5.9)
# Num Iterations: 256	Train: 96.3% (±5.0), Test: 90.4% (±5.4)
# Num Iterations: 512	Train: 96.8% (±4.3), Test: 90.6% (±5.6)
# Num Iterations: 1024	Train: 96.5% (±5.0), Test: 90.3% (±5.8)

# %% [markdown]
# ## Analysis
#
# From the above results, in general for our dataset, we can conclude the following:
#
# Regarding the optimization method:
#
# - L-BFGS-B achieves the best accuracy in the test set and also the best fit of the train set.
#
# Regarding the hidden layer size:
#
# - In average, the best accuracy on test set was achieved by the network with 64 neurons.
# - Hidden layer smaller than or equal to 8 tends to underfitting
# - Hidden layer higher than 128 does not contribute to accuracy.
#
# Regarding the regularization term:
#
# - Values of $\lambda$ smaller than $1.00$ have almost no impact on train set accuracy, but having no regularization leads to worst accuracy on test set.
# - $\lambda=5$ tends to decrease the accuracy in both train and test sets.
# - The best values of $\lambda$ go around $1.00$ and $3.00$.
#
# Regarding the number of iterations:
# - Higher Numbers of iterations tend to generate overfitting on train set.
# - Lower numbers of iterations ($< 128$) make the models have some underfitting.
# - However, the performance on test set for those cases do not decrease significantly.
# - The best number of iterations goes around $256$ and $512$.
